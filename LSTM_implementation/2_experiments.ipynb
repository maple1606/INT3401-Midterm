# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
from dotenv import load_dotenv

load_dotenv()

N_CLUSTERS = 4
april_dfs = pickle.load(open('/media/hoangbaoan1901/4F44EC2A29F10E55/information-systems_UET/BTL_AI/INT3401-Midterm/LSTM_implementation/data/april_cluster_row_col_dfs.pk', 'rb'))
october_dfs = pickle.load(open('/media/hoangbaoan1901/4F44EC2A29F10E55/information-systems_UET/BTL_AI/INT3401-Midterm/LSTM_implementation/data/october_cluster_row_col_dfs.pkl', 'rb'))

# %% [markdown]
# ## Helper functions to process time series data

# %%
def find_continuous(df: pd.DataFrame):
	"""
	Find continuous hourly segments in a DataFrame where rows are exactly 1 hour apart.

	Args:
		df (pd.DataFrame): DataFrame to search with a datetime index named 'date'.
						The index must be sorted in ascending order.

	Returns:
		list[pd.DataFrame]: List of DataFrame segments where rows are continuously
						1 hour apart. Each segment contains rows where the time 
						difference between consecutive rows is exactly 1 hour.

	Notes:
		- The function assumes the DataFrame's index is a datetime index
		- The function splits the DataFrame whenever there's a gap larger than 1 hour
		- Target value (here AWS) must not be null (pre-filtered with SQL query)
	"""
	continuous_index = []
	start = 0
	for i in range(1, len(df)):
		if (df.iloc[i]['date'] - df.iloc[i - 1]['date']) == pd.Timedelta(hours=1):
			continue
		else:
			continuous_index.append(tuple([start, i]))
			start = i
	continuous_index.append(tuple([start, len(df)]))
	continuous_df = [df.iloc[start:end].drop(columns=['date']) for start, end in continuous_index]
	print(f"find_continuous: len(continuous_df): {len(continuous_df)}")
	return continuous_df


def create_sequence_data(df: pd.DataFrame, time_step: int = 1, forward_step: int = 1, target_col: str = 'aws'):
	"""
	Create sequences of data from a DataFrame.

	Args:
			df (pd.DataFrame): DataFrame to process
			time_step (int): Number of time steps to include in each sequence
						forward_step (int): Number of steps to forecast into the future
	Returns:
						X (np.ndarray): Array of input sequences
						y (np.ndarray): Array of output sequences
	"""

	if (time_step < 1 or forward_step < 1):
		raise ValueError("time_step and forward step must be greater than 0")

	if (time_step + (forward_step - 1) >= len(df) - 1):
		raise ValueError(
			f"time_step ({time_step}) must be less than the length of the DataFrame({len(df)})")
	X = []
	y = []
	for i in range(len(df) - (time_step + (forward_step - 1))):
		X.append(df.iloc[i:i + time_step])
		y.append(df.iloc[i + time_step + (forward_step - 1)][target_col])

	X = np.array(X)
	y = np.array(y)
	print(f"create_sequence_data: X shape: {X.shape}, y shape: {y.shape}")
	return X, y


def get_data(df: pd.DataFrame, time_step: int = 1, forward_step: int = 1):
	"""
	Process the whole data frame to get X and y.
	"""
	final_X = []
	final_y = []
	continuous_dataframes = find_continuous(df)
	for dataframe in continuous_dataframes:
		try:
			X, y = create_sequence_data(dataframe, time_step, forward_step)
			for i in range(len(X)):
				final_X.append(X[i])
				final_y.append(y[i])
		except ValueError:
			pass
	
	final_X = np.array(final_X)
	final_y = np.array(final_y)
	print(f"get_data: final_X shape: {final_X.shape}, final_y shape: {final_y.shape}")
	return final_X, final_y

# %%
# Function to determines rain level
def rain_level(x):
	if x <= 0.1:
		return "No rain"
	elif x < 2.5:
		return "Slight rain"
	elif x < 10:
		return "Moderate rain"
	elif x < 50:
		return "Heavy rain"
	else:
		return "Violent rain"

# %% [markdown]
# # Training Flow
# 1. Determine time_lag and future time_step
# 	- Initialize dataset for april-cluster and october-cluster
# 2. Classify:
# 	- Rain or no rain using the **LAST LAG** in the input data
# 	- Imbalance learning: use SMOTE-EEN
# 	- Use Random Forest to determine rain or no rain
# 3. Regression:
# 	- If input is classified as rain, use LSTM to predict rain

# %% [markdown]
# ## Determine time_step and forward_step, then Initialize dataset for april-cluster and october-cluster

# %%
# Determine time_step and forward_step
TIME_STEP = 6
FORWARD_STEP = 1

# %%
# Initialize dataset for april_cluster and october_cluster
"""
Format:
april_dataset = [[X, y], [X, y], ...] # 4 clusters
october_dataset = [[X, y], [X, y], ...] # 4 clusters
"""
april_dataset = []
october_dataset = []
def get_data_for_cluster(df_dict, time_step, forward_step):
	X = []
	y = []
	for key in df_dict.keys():
		df = df_dict[key]
		print(f"df.shape: {df.shape}")
		X_temp, y_temp = get_data(df, time_step, forward_step)
		# Watch out for empty data
		if X_temp.size == 0  or y_temp.size == 0:
			continue
		X.append(X_temp)
		y.append(y_temp)
		print(f"X: {X_temp.shape}, y: {y_temp.shape}")
	# Concatenate all the data
	X = np.concatenate(X)
	y = np.concatenate(y)
	if X.size == 0 or y.size == 0:
		raise ValueError("X or y is empty")
	if X.shape[0] != y.shape[0]:
		raise ValueError("X and y must have the same number of samples")
	return X, y

for i in range(N_CLUSTERS):
	april_X, april_y = get_data_for_cluster(april_dfs[i], TIME_STEP, FORWARD_STEP)
	october_X, october_y = get_data_for_cluster(october_dfs[i], TIME_STEP, FORWARD_STEP)
	april_cluster_datset = [april_X, april_y]
	october_cluster_datset = [october_X, october_y]
	april_dataset.append(april_cluster_datset)
	october_dataset.append(october_cluster_datset)
# Out:
# df.shape: (962, 24)
# find_continuous: len(continuous_df): 126
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (216, 6, 23), y shape: (216,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (71, 6, 23), y shape: (71,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (4, 6, 23), y shape: (4,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# get_data: final_X shape: (591, 6, 23), final_y shape: (591,)
# X: (591, 6, 23), y: (591,)
# df.shape: (532, 24)
# find_continuous: len(continuous_df): 43
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (11, 6, 23), y shape: (11,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (11, 6, 23), y shape: (11,)
# create_sequence_data: X shape: (15, 6, 23), y shape: (15,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (4, 6, 23), y shape: (4,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# get_data: final_X shape: (304, 6, 23), final_y shape: (304,)
# X: (304, 6, 23), y: (304,)
# df.shape: (1278, 24)
# find_continuous: len(continuous_df): 33
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (171, 6, 23), y shape: (171,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (52, 6, 23), y shape: (52,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (103, 6, 23), y shape: (103,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (59, 6, 23), y shape: (59,)
# create_sequence_data: X shape: (76, 6, 23), y shape: (76,)
# create_sequence_data: X shape: (19, 6, 23), y shape: (19,)
# create_sequence_data: X shape: (37, 6, 23), y shape: (37,)
# create_sequence_data: X shape: (12, 6, 23), y shape: (12,)
# create_sequence_data: X shape: (93, 6, 23), y shape: (93,)
# create_sequence_data: X shape: (209, 6, 23), y shape: (209,)
# get_data: final_X shape: (1123, 6, 23), final_y shape: (1123,)
# X: (1123, 6, 23), y: (1123,)
# df.shape: (1277, 24)
# find_continuous: len(continuous_df): 31
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (171, 6, 23), y shape: (171,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (52, 6, 23), y shape: (52,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (118, 6, 23), y shape: (118,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (59, 6, 23), y shape: (59,)
# create_sequence_data: X shape: (76, 6, 23), y shape: (76,)
# create_sequence_data: X shape: (19, 6, 23), y shape: (19,)
# create_sequence_data: X shape: (37, 6, 23), y shape: (37,)
# create_sequence_data: X shape: (12, 6, 23), y shape: (12,)
# create_sequence_data: X shape: (93, 6, 23), y shape: (93,)
# create_sequence_data: X shape: (209, 6, 23), y shape: (209,)
# get_data: final_X shape: (1136, 6, 23), final_y shape: (1136,)
# X: (1136, 6, 23), y: (1136,)
# df.shape: (1281, 24)
# find_continuous: len(continuous_df): 31
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (171, 6, 23), y shape: (171,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (52, 6, 23), y shape: (52,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (118, 6, 23), y shape: (118,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (59, 6, 23), y shape: (59,)
# create_sequence_data: X shape: (76, 6, 23), y shape: (76,)
# create_sequence_data: X shape: (19, 6, 23), y shape: (19,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (37, 6, 23), y shape: (37,)
# create_sequence_data: X shape: (12, 6, 23), y shape: (12,)
# create_sequence_data: X shape: (93, 6, 23), y shape: (93,)
# create_sequence_data: X shape: (10, 6, 23), y shape: (10,)
# create_sequence_data: X shape: (192, 6, 23), y shape: (192,)
# get_data: final_X shape: (1134, 6, 23), final_y shape: (1134,)
# X: (1134, 6, 23), y: (1134,)
# df.shape: (926, 24)
# find_continuous: len(continuous_df): 132
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (216, 6, 23), y shape: (216,)
# create_sequence_data: X shape: (67, 6, 23), y shape: (67,)
# create_sequence_data: X shape: (108, 6, 23), y shape: (108,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (71, 6, 23), y shape: (71,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (4, 6, 23), y shape: (4,)
# create_sequence_data: X shape: (4, 6, 23), y shape: (4,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# get_data: final_X shape: (566, 6, 23), final_y shape: (566,)
# X: (566, 6, 23), y: (566,)
# df.shape: (1282, 24)
# find_continuous: len(continuous_df): 29
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (171, 6, 23), y shape: (171,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (52, 6, 23), y shape: (52,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (118, 6, 23), y shape: (118,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (59, 6, 23), y shape: (59,)
# create_sequence_data: X shape: (76, 6, 23), y shape: (76,)
# create_sequence_data: X shape: (19, 6, 23), y shape: (19,)
# create_sequence_data: X shape: (4, 6, 23), y shape: (4,)
# create_sequence_data: X shape: (37, 6, 23), y shape: (37,)
# create_sequence_data: X shape: (12, 6, 23), y shape: (12,)
# create_sequence_data: X shape: (95, 6, 23), y shape: (95,)
# create_sequence_data: X shape: (209, 6, 23), y shape: (209,)
# get_data: final_X shape: (1142, 6, 23), final_y shape: (1142,)
# X: (1142, 6, 23), y: (1142,)
# df.shape: (11, 24)
# find_continuous: len(continuous_df): 11
# get_data: final_X shape: (0,), final_y shape: (0,)
# df.shape: (1279, 24)
# find_continuous: len(continuous_df): 31
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (171, 6, 23), y shape: (171,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (52, 6, 23), y shape: (52,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (118, 6, 23), y shape: (118,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (59, 6, 23), y shape: (59,)
# create_sequence_data: X shape: (76, 6, 23), y shape: (76,)
# create_sequence_data: X shape: (19, 6, 23), y shape: (19,)
# create_sequence_data: X shape: (37, 6, 23), y shape: (37,)
# create_sequence_data: X shape: (12, 6, 23), y shape: (12,)
# create_sequence_data: X shape: (95, 6, 23), y shape: (95,)
# create_sequence_data: X shape: (33, 6, 23), y shape: (33,)
# create_sequence_data: X shape: (169, 6, 23), y shape: (169,)
# get_data: final_X shape: (1131, 6, 23), final_y shape: (1131,)
# X: (1131, 6, 23), y: (1131,)
# df.shape: (736, 24)
# find_continuous: len(continuous_df): 13
# create_sequence_data: X shape: (11, 6, 23), y shape: (11,)
# create_sequence_data: X shape: (18, 6, 23), y shape: (18,)
# create_sequence_data: X shape: (63, 6, 23), y shape: (63,)
# create_sequence_data: X shape: (37, 6, 23), y shape: (37,)
# create_sequence_data: X shape: (40, 6, 23), y shape: (40,)
# create_sequence_data: X shape: (91, 6, 23), y shape: (91,)
# create_sequence_data: X shape: (12, 6, 23), y shape: (12,)
# create_sequence_data: X shape: (279, 6, 23), y shape: (279,)
# create_sequence_data: X shape: (77, 6, 23), y shape: (77,)
# create_sequence_data: X shape: (38, 6, 23), y shape: (38,)
# get_data: final_X shape: (666, 6, 23), final_y shape: (666,)
# X: (666, 6, 23), y: (666,)
# df.shape: (1283, 24)
# find_continuous: len(continuous_df): 29
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (171, 6, 23), y shape: (171,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (52, 6, 23), y shape: (52,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (118, 6, 23), y shape: (118,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (59, 6, 23), y shape: (59,)
# create_sequence_data: X shape: (76, 6, 23), y shape: (76,)
# create_sequence_data: X shape: (19, 6, 23), y shape: (19,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (37, 6, 23), y shape: (37,)
# create_sequence_data: X shape: (12, 6, 23), y shape: (12,)
# create_sequence_data: X shape: (95, 6, 23), y shape: (95,)
# create_sequence_data: X shape: (209, 6, 23), y shape: (209,)
# get_data: final_X shape: (1143, 6, 23), final_y shape: (1143,)
# X: (1143, 6, 23), y: (1143,)
# df.shape: (358, 24)
# find_continuous: len(continuous_df): 111
# create_sequence_data: X shape: (12, 6, 23), y shape: (12,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# get_data: final_X shape: (30, 6, 23), final_y shape: (30,)
# X: (30, 6, 23), y: (30,)
# df.shape: (7, 24)
# find_continuous: len(continuous_df): 7
# get_data: final_X shape: (0,), final_y shape: (0,)
# df.shape: (960, 24)
# find_continuous: len(continuous_df): 132
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (216, 6, 23), y shape: (216,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (71, 6, 23), y shape: (71,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# get_data: final_X shape: (584, 6, 23), final_y shape: (584,)
# X: (584, 6, 23), y: (584,)
# df.shape: (1215, 24)
# find_continuous: len(continuous_df): 54
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (11, 6, 23), y shape: (11,)
# create_sequence_data: X shape: (10, 6, 23), y shape: (10,)
# create_sequence_data: X shape: (11, 6, 23), y shape: (11,)
# create_sequence_data: X shape: (15, 6, 23), y shape: (15,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (4, 6, 23), y shape: (4,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (15, 6, 23), y shape: (15,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (62, 6, 23), y shape: (62,)
# create_sequence_data: X shape: (32, 6, 23), y shape: (32,)
# create_sequence_data: X shape: (105, 6, 23), y shape: (105,)
# create_sequence_data: X shape: (23, 6, 23), y shape: (23,)
# create_sequence_data: X shape: (18, 6, 23), y shape: (18,)
# create_sequence_data: X shape: (228, 6, 23), y shape: (228,)
# create_sequence_data: X shape: (10, 6, 23), y shape: (10,)
# create_sequence_data: X shape: (16, 6, 23), y shape: (16,)
# create_sequence_data: X shape: (10, 6, 23), y shape: (10,)
# create_sequence_data: X shape: (60, 6, 23), y shape: (60,)
# create_sequence_data: X shape: (39, 6, 23), y shape: (39,)
# get_data: final_X shape: (929, 6, 23), final_y shape: (929,)
# X: (929, 6, 23), y: (929,)
# df.shape: (370, 24)
# find_continuous: len(continuous_df): 129
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (4, 6, 23), y shape: (4,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# get_data: final_X shape: (20, 6, 23), final_y shape: (20,)
# X: (20, 6, 23), y: (20,)
# df.shape: (1215, 24)
# find_continuous: len(continuous_df): 57
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (11, 6, 23), y shape: (11,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (15, 6, 23), y shape: (15,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (14, 6, 23), y shape: (14,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (4, 6, 23), y shape: (4,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (62, 6, 23), y shape: (62,)
# create_sequence_data: X shape: (37, 6, 23), y shape: (37,)
# create_sequence_data: X shape: (38, 6, 23), y shape: (38,)
# create_sequence_data: X shape: (86, 6, 23), y shape: (86,)
# create_sequence_data: X shape: (11, 6, 23), y shape: (11,)
# create_sequence_data: X shape: (221, 6, 23), y shape: (221,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (15, 6, 23), y shape: (15,)
# create_sequence_data: X shape: (77, 6, 23), y shape: (77,)
# create_sequence_data: X shape: (30, 6, 23), y shape: (30,)
# get_data: final_X shape: (916, 6, 23), final_y shape: (916,)
# X: (916, 6, 23), y: (916,)
# df.shape: (943, 24)
# find_continuous: len(continuous_df): 134
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (216, 6, 23), y shape: (216,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (71, 6, 23), y shape: (71,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (12, 6, 23), y shape: (12,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# get_data: final_X shape: (588, 6, 23), final_y shape: (588,)
# X: (588, 6, 23), y: (588,)
# df.shape: (1281, 24)
# find_continuous: len(continuous_df): 31
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (171, 6, 23), y shape: (171,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (52, 6, 23), y shape: (52,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (118, 6, 23), y shape: (118,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (59, 6, 23), y shape: (59,)
# create_sequence_data: X shape: (76, 6, 23), y shape: (76,)
# create_sequence_data: X shape: (19, 6, 23), y shape: (19,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (37, 6, 23), y shape: (37,)
# create_sequence_data: X shape: (12, 6, 23), y shape: (12,)
# create_sequence_data: X shape: (93, 6, 23), y shape: (93,)
# create_sequence_data: X shape: (11, 6, 23), y shape: (11,)
# create_sequence_data: X shape: (191, 6, 23), y shape: (191,)
# get_data: final_X shape: (1134, 6, 23), final_y shape: (1134,)
# X: (1134, 6, 23), y: (1134,)
# df.shape: (967, 24)
# find_continuous: len(continuous_df): 124
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (216, 6, 23), y shape: (216,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (71, 6, 23), y shape: (71,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (12, 6, 23), y shape: (12,)
# create_sequence_data: X shape: (4, 6, 23), y shape: (4,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (6, 6, 23), y shape: (6,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# get_data: final_X shape: (600, 6, 23), final_y shape: (600,)
# X: (600, 6, 23), y: (600,)
# df.shape: (951, 24)
# find_continuous: len(continuous_df): 125
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (216, 6, 23), y shape: (216,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (71, 6, 23), y shape: (71,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (4, 6, 23), y shape: (4,)
# create_sequence_data: X shape: (4, 6, 23), y shape: (4,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (6, 6, 23), y shape: (6,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# get_data: final_X shape: (589, 6, 23), final_y shape: (589,)
# X: (589, 6, 23), y: (589,)
# df.shape: (958, 24)
# find_continuous: len(continuous_df): 125
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (214, 6, 23), y shape: (214,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (71, 6, 23), y shape: (71,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (21, 6, 23), y shape: (21,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# get_data: final_X shape: (602, 6, 23), final_y shape: (602,)
# X: (602, 6, 23), y: (602,)
# df.shape: (942, 24)
# find_continuous: len(continuous_df): 128
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (216, 6, 23), y shape: (216,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (71, 6, 23), y shape: (71,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (12, 6, 23), y shape: (12,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# get_data: final_X shape: (579, 6, 23), final_y shape: (579,)
# X: (579, 6, 23), y: (579,)
# df.shape: (692, 24)
# find_continuous: len(continuous_df): 13
# create_sequence_data: X shape: (40, 6, 23), y shape: (40,)
# create_sequence_data: X shape: (16, 6, 23), y shape: (16,)
# create_sequence_data: X shape: (37, 6, 23), y shape: (37,)
# create_sequence_data: X shape: (162, 6, 23), y shape: (162,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (14, 6, 23), y shape: (14,)
# create_sequence_data: X shape: (13, 6, 23), y shape: (13,)
# create_sequence_data: X shape: (42, 6, 23), y shape: (42,)
# create_sequence_data: X shape: (165, 6, 23), y shape: (165,)
# create_sequence_data: X shape: (82, 6, 23), y shape: (82,)
# create_sequence_data: X shape: (41, 6, 23), y shape: (41,)
# get_data: final_X shape: (621, 6, 23), final_y shape: (621,)
# X: (621, 6, 23), y: (621,)
# df.shape: (948, 24)
# find_continuous: len(continuous_df): 117
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (216, 6, 23), y shape: (216,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (71, 6, 23), y shape: (71,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (21, 6, 23), y shape: (21,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# get_data: final_X shape: (598, 6, 23), final_y shape: (598,)
# X: (598, 6, 23), y: (598,)
# df.shape: (923, 24)
# find_continuous: len(continuous_df): 116
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (216, 6, 23), y shape: (216,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (71, 6, 23), y shape: (71,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (4, 6, 23), y shape: (4,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# get_data: final_X shape: (573, 6, 23), final_y shape: (573,)
# X: (573, 6, 23), y: (573,)
# df.shape: (1250, 24)
# find_continuous: len(continuous_df): 34
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (216, 6, 23), y shape: (216,)
# create_sequence_data: X shape: (53, 6, 23), y shape: (53,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (26, 6, 23), y shape: (26,)
# create_sequence_data: X shape: (38, 6, 23), y shape: (38,)
# create_sequence_data: X shape: (13, 6, 23), y shape: (13,)
# create_sequence_data: X shape: (10, 6, 23), y shape: (10,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (14, 6, 23), y shape: (14,)
# create_sequence_data: X shape: (28, 6, 23), y shape: (28,)
# create_sequence_data: X shape: (4, 6, 23), y shape: (4,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (22, 6, 23), y shape: (22,)
# create_sequence_data: X shape: (58, 6, 23), y shape: (58,)
# create_sequence_data: X shape: (33, 6, 23), y shape: (33,)
# create_sequence_data: X shape: (162, 6, 23), y shape: (162,)
# create_sequence_data: X shape: (33, 6, 23), y shape: (33,)
# create_sequence_data: X shape: (243, 6, 23), y shape: (243,)
# create_sequence_data: X shape: (64, 6, 23), y shape: (64,)
# create_sequence_data: X shape: (38, 6, 23), y shape: (38,)
# get_data: final_X shape: (1091, 6, 23), final_y shape: (1091,)
# X: (1091, 6, 23), y: (1091,)
# df.shape: (1283, 24)
# find_continuous: len(continuous_df): 29
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (171, 6, 23), y shape: (171,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (52, 6, 23), y shape: (52,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (118, 6, 23), y shape: (118,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (59, 6, 23), y shape: (59,)
# create_sequence_data: X shape: (76, 6, 23), y shape: (76,)
# create_sequence_data: X shape: (19, 6, 23), y shape: (19,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (37, 6, 23), y shape: (37,)
# create_sequence_data: X shape: (12, 6, 23), y shape: (12,)
# create_sequence_data: X shape: (95, 6, 23), y shape: (95,)
# create_sequence_data: X shape: (209, 6, 23), y shape: (209,)
# get_data: final_X shape: (1143, 6, 23), final_y shape: (1143,)
# X: (1143, 6, 23), y: (1143,)
# df.shape: (1282, 24)
# find_continuous: len(continuous_df): 30
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (171, 6, 23), y shape: (171,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (52, 6, 23), y shape: (52,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (118, 6, 23), y shape: (118,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (59, 6, 23), y shape: (59,)
# create_sequence_data: X shape: (76, 6, 23), y shape: (76,)
# create_sequence_data: X shape: (19, 6, 23), y shape: (19,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (37, 6, 23), y shape: (37,)
# create_sequence_data: X shape: (12, 6, 23), y shape: (12,)
# create_sequence_data: X shape: (93, 6, 23), y shape: (93,)
# create_sequence_data: X shape: (209, 6, 23), y shape: (209,)
# get_data: final_X shape: (1141, 6, 23), final_y shape: (1141,)
# X: (1141, 6, 23), y: (1141,)
# df.shape: (349, 24)
# find_continuous: len(continuous_df): 115
# create_sequence_data: X shape: (12, 6, 23), y shape: (12,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# get_data: final_X shape: (44, 6, 23), final_y shape: (44,)
# X: (44, 6, 23), y: (44,)
# df.shape: (24, 24)
# find_continuous: len(continuous_df): 24
# get_data: final_X shape: (0,), final_y shape: (0,)
# df.shape: (465, 24)
# find_continuous: len(continuous_df): 68
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (16, 6, 23), y shape: (16,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (11, 6, 23), y shape: (11,)
# create_sequence_data: X shape: (6, 6, 23), y shape: (6,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (6, 6, 23), y shape: (6,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# get_data: final_X shape: (177, 6, 23), final_y shape: (177,)
# X: (177, 6, 23), y: (177,)
# df.shape: (1211, 24)
# find_continuous: len(continuous_df): 62
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (11, 6, 23), y shape: (11,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (15, 6, 23), y shape: (15,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (4, 6, 23), y shape: (4,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (11, 6, 23), y shape: (11,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (27, 6, 23), y shape: (27,)
# create_sequence_data: X shape: (28, 6, 23), y shape: (28,)
# create_sequence_data: X shape: (37, 6, 23), y shape: (37,)
# create_sequence_data: X shape: (33, 6, 23), y shape: (33,)
# create_sequence_data: X shape: (89, 6, 23), y shape: (89,)
# create_sequence_data: X shape: (11, 6, 23), y shape: (11,)
# create_sequence_data: X shape: (222, 6, 23), y shape: (222,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (15, 6, 23), y shape: (15,)
# create_sequence_data: X shape: (13, 6, 23), y shape: (13,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (38, 6, 23), y shape: (38,)
# get_data: final_X shape: (896, 6, 23), final_y shape: (896,)
# X: (896, 6, 23), y: (896,)
# df.shape: (969, 24)
# find_continuous: len(continuous_df): 134
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (206, 6, 23), y shape: (206,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (71, 6, 23), y shape: (71,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# get_data: final_X shape: (590, 6, 23), final_y shape: (590,)
# X: (590, 6, 23), y: (590,)
# df.shape: (963, 24)
# find_continuous: len(continuous_df): 132
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (216, 6, 23), y shape: (216,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (71, 6, 23), y shape: (71,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (10, 6, 23), y shape: (10,)
# create_sequence_data: X shape: (22, 6, 23), y shape: (22,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# get_data: final_X shape: (591, 6, 23), final_y shape: (591,)
# X: (591, 6, 23), y: (591,)
# df.shape: (304, 24)
# find_continuous: len(continuous_df): 129
# create_sequence_data: X shape: (12, 6, 23), y shape: (12,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (6, 6, 23), y shape: (6,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# get_data: final_X shape: (25, 6, 23), final_y shape: (25,)
# X: (25, 6, 23), y: (25,)
# df.shape: (1282, 24)
# find_continuous: len(continuous_df): 30
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (171, 6, 23), y shape: (171,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (52, 6, 23), y shape: (52,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (118, 6, 23), y shape: (118,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (59, 6, 23), y shape: (59,)
# create_sequence_data: X shape: (76, 6, 23), y shape: (76,)
# create_sequence_data: X shape: (19, 6, 23), y shape: (19,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (37, 6, 23), y shape: (37,)
# create_sequence_data: X shape: (12, 6, 23), y shape: (12,)
# create_sequence_data: X shape: (4, 6, 23), y shape: (4,)
# create_sequence_data: X shape: (84, 6, 23), y shape: (84,)
# create_sequence_data: X shape: (209, 6, 23), y shape: (209,)
# get_data: final_X shape: (1136, 6, 23), final_y shape: (1136,)
# X: (1136, 6, 23), y: (1136,)
# df.shape: (961, 24)
# find_continuous: len(continuous_df): 128
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (216, 6, 23), y shape: (216,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (71, 6, 23), y shape: (71,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (41, 6, 23), y shape: (41,)
# create_sequence_data: X shape: (6, 6, 23), y shape: (6,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (4, 6, 23), y shape: (4,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# get_data: final_X shape: (589, 6, 23), final_y shape: (589,)
# X: (589, 6, 23), y: (589,)
# df.shape: (1279, 24)
# find_continuous: len(continuous_df): 33
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (171, 6, 23), y shape: (171,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (52, 6, 23), y shape: (52,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (14, 6, 23), y shape: (14,)
# create_sequence_data: X shape: (97, 6, 23), y shape: (97,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (59, 6, 23), y shape: (59,)
# create_sequence_data: X shape: (24, 6, 23), y shape: (24,)
# create_sequence_data: X shape: (29, 6, 23), y shape: (29,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (19, 6, 23), y shape: (19,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (37, 6, 23), y shape: (37,)
# create_sequence_data: X shape: (12, 6, 23), y shape: (12,)
# create_sequence_data: X shape: (93, 6, 23), y shape: (93,)
# create_sequence_data: X shape: (209, 6, 23), y shape: (209,)
# get_data: final_X shape: (1120, 6, 23), final_y shape: (1120,)
# X: (1120, 6, 23), y: (1120,)
# df.shape: (429, 24)
# find_continuous: len(continuous_df): 108
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (11, 6, 23), y shape: (11,)
# create_sequence_data: X shape: (12, 6, 23), y shape: (12,)
# create_sequence_data: X shape: (10, 6, 23), y shape: (10,)
# create_sequence_data: X shape: (11, 6, 23), y shape: (11,)
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (13, 6, 23), y shape: (13,)
# get_data: final_X shape: (119, 6, 23), final_y shape: (119,)
# X: (119, 6, 23), y: (119,)
# df.shape: (946, 24)
# find_continuous: len(continuous_df): 132
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (216, 6, 23), y shape: (216,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (71, 6, 23), y shape: (71,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (10, 6, 23), y shape: (10,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# get_data: final_X shape: (568, 6, 23), final_y shape: (568,)
# X: (568, 6, 23), y: (568,)
# df.shape: (369, 24)
# find_continuous: len(continuous_df): 128
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# get_data: final_X shape: (31, 6, 23), final_y shape: (31,)
# X: (31, 6, 23), y: (31,)
# df.shape: (225, 24)
# find_continuous: len(continuous_df): 151
# get_data: final_X shape: (0,), final_y shape: (0,)
# df.shape: (1025, 24)
# find_continuous: len(continuous_df): 129
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (216, 6, 23), y shape: (216,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (71, 6, 23), y shape: (71,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (12, 6, 23), y shape: (12,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (4, 6, 23), y shape: (4,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (10, 6, 23), y shape: (10,)
# get_data: final_X shape: (603, 6, 23), final_y shape: (603,)
# X: (603, 6, 23), y: (603,)
# df.shape: (379, 24)
# find_continuous: len(continuous_df): 123
# create_sequence_data: X shape: (4, 6, 23), y shape: (4,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# get_data: final_X shape: (33, 6, 23), final_y shape: (33,)
# X: (33, 6, 23), y: (33,)
# df.shape: (367, 24)
# find_continuous: len(continuous_df): 128
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (6, 6, 23), y shape: (6,)
# create_sequence_data: X shape: (2, 6, 23), y shape: (2,)
# create_sequence_data: X shape: (4, 6, 23), y shape: (4,)
# get_data: final_X shape: (25, 6, 23), final_y shape: (25,)
# X: (25, 6, 23), y: (25,)
# df.shape: (968, 24)
# find_continuous: len(continuous_df): 128
# create_sequence_data: X shape: (9, 6, 23), y shape: (9,)
# create_sequence_data: X shape: (216, 6, 23), y shape: (216,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (71, 6, 23), y shape: (71,)
# create_sequence_data: X shape: (57, 6, 23), y shape: (57,)
# create_sequence_data: X shape: (15, 6, 23), y shape: (15,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (4, 6, 23), y shape: (4,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# get_data: final_X shape: (599, 6, 23), final_y shape: (599,)
# X: (599, 6, 23), y: (599,)
# df.shape: (373, 24)
# find_continuous: len(continuous_df): 118
# create_sequence_data: X shape: (12, 6, 23), y shape: (12,)
# create_sequence_data: X shape: (4, 6, 23), y shape: (4,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (4, 6, 23), y shape: (4,)
# create_sequence_data: X shape: (8, 6, 23), y shape: (8,)
# get_data: final_X shape: (46, 6, 23), final_y shape: (46,)
# X: (46, 6, 23), y: (46,)
# df.shape: (1282, 24)
# find_continuous: len(continuous_df): 30
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# create_sequence_data: X shape: (7, 6, 23), y shape: (7,)
# create_sequence_data: X shape: (5, 6, 23), y shape: (5,)
# create_sequence_data: X shape: (171, 6, 23), y shape: (171,)
# create_sequence_data: X shape: (182, 6, 23), y shape: (182,)
# create_sequence_data: X shape: (17, 6, 23), y shape: (17,)
# create_sequence_data: X shape: (3, 6, 23), y shape: (3,)
# ...
# create_sequence_data: X shape: (3, 6, 24), y shape: (3,)
# create_sequence_data: X shape: (27, 6, 24), y shape: (27,)
# create_sequence_data: X shape: (21, 6, 24), y shape: (21,)
# create_sequence_data: X shape: (21, 6, 24), y shape: (21,)
# create_sequence_data: X shape: (425, 6, 24), y shape: (425,)
# create_sequence_data: X shape: (58, 6, 24), y shape: (58,)
# create_sequence_data: X shape: (22, 6, 24), y shape: (22,)
# create_sequence_data: X shape: (18, 6, 24), y shape: (18,)
# create_sequence_data: X shape: (18, 6, 24), y shape: (18,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (65, 6, 24), y shape: (65,)
# get_data: final_X shape: (974, 6, 24), final_y shape: (974,)
# X: (974, 6, 24), y: (974,)
# df.shape: (1006, 25)
# find_continuous: len(continuous_df): 101
# create_sequence_data: X shape: (4, 6, 24), y shape: (4,)
# create_sequence_data: X shape: (2, 6, 24), y shape: (2,)
# create_sequence_data: X shape: (2, 6, 24), y shape: (2,)
# create_sequence_data: X shape: (5, 6, 24), y shape: (5,)
# create_sequence_data: X shape: (8, 6, 24), y shape: (8,)
# create_sequence_data: X shape: (3, 6, 24), y shape: (3,)
# create_sequence_data: X shape: (2, 6, 24), y shape: (2,)
# create_sequence_data: X shape: (2, 6, 24), y shape: (2,)
# create_sequence_data: X shape: (2, 6, 24), y shape: (2,)
# create_sequence_data: X shape: (4, 6, 24), y shape: (4,)
# create_sequence_data: X shape: (21, 6, 24), y shape: (21,)
# create_sequence_data: X shape: (63, 6, 24), y shape: (63,)
# create_sequence_data: X shape: (355, 6, 24), y shape: (355,)
# create_sequence_data: X shape: (58, 6, 24), y shape: (58,)
# create_sequence_data: X shape: (48, 6, 24), y shape: (48,)
# create_sequence_data: X shape: (18, 6, 24), y shape: (18,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (65, 6, 24), y shape: (65,)
# get_data: final_X shape: (673, 6, 24), final_y shape: (673,)
# X: (673, 6, 24), y: (673,)
# df.shape: (1165, 25)
# find_continuous: len(continuous_df): 42
# create_sequence_data: X shape: (75, 6, 24), y shape: (75,)
# create_sequence_data: X shape: (5, 6, 24), y shape: (5,)
# create_sequence_data: X shape: (64, 6, 24), y shape: (64,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (6, 6, 24), y shape: (6,)
# create_sequence_data: X shape: (5, 6, 24), y shape: (5,)
# create_sequence_data: X shape: (10, 6, 24), y shape: (10,)
# create_sequence_data: X shape: (8, 6, 24), y shape: (8,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (36, 6, 24), y shape: (36,)
# create_sequence_data: X shape: (41, 6, 24), y shape: (41,)
# create_sequence_data: X shape: (14, 6, 24), y shape: (14,)
# create_sequence_data: X shape: (3, 6, 24), y shape: (3,)
# create_sequence_data: X shape: (27, 6, 24), y shape: (27,)
# create_sequence_data: X shape: (24, 6, 24), y shape: (24,)
# create_sequence_data: X shape: (15, 6, 24), y shape: (15,)
# create_sequence_data: X shape: (425, 6, 24), y shape: (425,)
# create_sequence_data: X shape: (58, 6, 24), y shape: (58,)
# create_sequence_data: X shape: (22, 6, 24), y shape: (22,)
# create_sequence_data: X shape: (18, 6, 24), y shape: (18,)
# create_sequence_data: X shape: (18, 6, 24), y shape: (18,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (63, 6, 24), y shape: (63,)
# get_data: final_X shape: (970, 6, 24), final_y shape: (970,)
# X: (970, 6, 24), y: (970,)
# df.shape: (1012, 25)
# find_continuous: len(continuous_df): 107
# create_sequence_data: X shape: (2, 6, 24), y shape: (2,)
# create_sequence_data: X shape: (3, 6, 24), y shape: (3,)
# create_sequence_data: X shape: (5, 6, 24), y shape: (5,)
# create_sequence_data: X shape: (2, 6, 24), y shape: (2,)
# create_sequence_data: X shape: (2, 6, 24), y shape: (2,)
# create_sequence_data: X shape: (4, 6, 24), y shape: (4,)
# create_sequence_data: X shape: (13, 6, 24), y shape: (13,)
# create_sequence_data: X shape: (3, 6, 24), y shape: (3,)
# create_sequence_data: X shape: (21, 6, 24), y shape: (21,)
# create_sequence_data: X shape: (425, 6, 24), y shape: (425,)
# create_sequence_data: X shape: (58, 6, 24), y shape: (58,)
# create_sequence_data: X shape: (25, 6, 24), y shape: (25,)
# create_sequence_data: X shape: (17, 6, 24), y shape: (17,)
# create_sequence_data: X shape: (18, 6, 24), y shape: (18,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (65, 6, 24), y shape: (65,)
# get_data: final_X shape: (674, 6, 24), final_y shape: (674,)
# X: (674, 6, 24), y: (674,)
# df.shape: (1168, 25)
# find_continuous: len(continuous_df): 43
# create_sequence_data: X shape: (75, 6, 24), y shape: (75,)
# create_sequence_data: X shape: (5, 6, 24), y shape: (5,)
# create_sequence_data: X shape: (64, 6, 24), y shape: (64,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (6, 6, 24), y shape: (6,)
# create_sequence_data: X shape: (5, 6, 24), y shape: (5,)
# create_sequence_data: X shape: (10, 6, 24), y shape: (10,)
# create_sequence_data: X shape: (8, 6, 24), y shape: (8,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (36, 6, 24), y shape: (36,)
# create_sequence_data: X shape: (41, 6, 24), y shape: (41,)
# create_sequence_data: X shape: (14, 6, 24), y shape: (14,)
# create_sequence_data: X shape: (3, 6, 24), y shape: (3,)
# create_sequence_data: X shape: (27, 6, 24), y shape: (27,)
# create_sequence_data: X shape: (24, 6, 24), y shape: (24,)
# create_sequence_data: X shape: (15, 6, 24), y shape: (15,)
# create_sequence_data: X shape: (23, 6, 24), y shape: (23,)
# create_sequence_data: X shape: (395, 6, 24), y shape: (395,)
# create_sequence_data: X shape: (58, 6, 24), y shape: (58,)
# create_sequence_data: X shape: (30, 6, 24), y shape: (30,)
# create_sequence_data: X shape: (18, 6, 24), y shape: (18,)
# create_sequence_data: X shape: (18, 6, 24), y shape: (18,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (63, 6, 24), y shape: (63,)
# get_data: final_X shape: (971, 6, 24), final_y shape: (971,)
# X: (971, 6, 24), y: (971,)
# df.shape: (1169, 25)
# find_continuous: len(continuous_df): 42
# create_sequence_data: X shape: (75, 6, 24), y shape: (75,)
# create_sequence_data: X shape: (5, 6, 24), y shape: (5,)
# create_sequence_data: X shape: (64, 6, 24), y shape: (64,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (6, 6, 24), y shape: (6,)
# create_sequence_data: X shape: (5, 6, 24), y shape: (5,)
# create_sequence_data: X shape: (10, 6, 24), y shape: (10,)
# create_sequence_data: X shape: (8, 6, 24), y shape: (8,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (36, 6, 24), y shape: (36,)
# create_sequence_data: X shape: (41, 6, 24), y shape: (41,)
# create_sequence_data: X shape: (14, 6, 24), y shape: (14,)
# create_sequence_data: X shape: (3, 6, 24), y shape: (3,)
# create_sequence_data: X shape: (27, 6, 24), y shape: (27,)
# create_sequence_data: X shape: (24, 6, 24), y shape: (24,)
# create_sequence_data: X shape: (15, 6, 24), y shape: (15,)
# create_sequence_data: X shape: (425, 6, 24), y shape: (425,)
# create_sequence_data: X shape: (58, 6, 24), y shape: (58,)
# create_sequence_data: X shape: (30, 6, 24), y shape: (30,)
# create_sequence_data: X shape: (18, 6, 24), y shape: (18,)
# create_sequence_data: X shape: (18, 6, 24), y shape: (18,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (63, 6, 24), y shape: (63,)
# get_data: final_X shape: (978, 6, 24), final_y shape: (978,)
# X: (978, 6, 24), y: (978,)
# df.shape: (1167, 25)
# find_continuous: len(continuous_df): 42
# create_sequence_data: X shape: (75, 6, 24), y shape: (75,)
# create_sequence_data: X shape: (5, 6, 24), y shape: (5,)
# create_sequence_data: X shape: (64, 6, 24), y shape: (64,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (6, 6, 24), y shape: (6,)
# create_sequence_data: X shape: (5, 6, 24), y shape: (5,)
# create_sequence_data: X shape: (10, 6, 24), y shape: (10,)
# create_sequence_data: X shape: (8, 6, 24), y shape: (8,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (36, 6, 24), y shape: (36,)
# create_sequence_data: X shape: (41, 6, 24), y shape: (41,)
# create_sequence_data: X shape: (14, 6, 24), y shape: (14,)
# create_sequence_data: X shape: (3, 6, 24), y shape: (3,)
# create_sequence_data: X shape: (27, 6, 24), y shape: (27,)
# create_sequence_data: X shape: (24, 6, 24), y shape: (24,)
# create_sequence_data: X shape: (15, 6, 24), y shape: (15,)
# create_sequence_data: X shape: (74, 6, 24), y shape: (74,)
# create_sequence_data: X shape: (344, 6, 24), y shape: (344,)
# create_sequence_data: X shape: (58, 6, 24), y shape: (58,)
# create_sequence_data: X shape: (30, 6, 24), y shape: (30,)
# create_sequence_data: X shape: (18, 6, 24), y shape: (18,)
# create_sequence_data: X shape: (18, 6, 24), y shape: (18,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (63, 6, 24), y shape: (63,)
# get_data: final_X shape: (971, 6, 24), final_y shape: (971,)
# X: (971, 6, 24), y: (971,)
# df.shape: (1176, 25)
# find_continuous: len(continuous_df): 38
# create_sequence_data: X shape: (75, 6, 24), y shape: (75,)
# create_sequence_data: X shape: (5, 6, 24), y shape: (5,)
# create_sequence_data: X shape: (64, 6, 24), y shape: (64,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (6, 6, 24), y shape: (6,)
# create_sequence_data: X shape: (5, 6, 24), y shape: (5,)
# create_sequence_data: X shape: (10, 6, 24), y shape: (10,)
# create_sequence_data: X shape: (8, 6, 24), y shape: (8,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (36, 6, 24), y shape: (36,)
# create_sequence_data: X shape: (62, 6, 24), y shape: (62,)
# create_sequence_data: X shape: (3, 6, 24), y shape: (3,)
# create_sequence_data: X shape: (27, 6, 24), y shape: (27,)
# create_sequence_data: X shape: (27, 6, 24), y shape: (27,)
# create_sequence_data: X shape: (21, 6, 24), y shape: (21,)
# create_sequence_data: X shape: (425, 6, 24), y shape: (425,)
# create_sequence_data: X shape: (58, 6, 24), y shape: (58,)
# create_sequence_data: X shape: (32, 6, 24), y shape: (32,)
# create_sequence_data: X shape: (18, 6, 24), y shape: (18,)
# create_sequence_data: X shape: (18, 6, 24), y shape: (18,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (65, 6, 24), y shape: (65,)
# get_data: final_X shape: (998, 6, 24), final_y shape: (998,)
# X: (998, 6, 24), y: (998,)
# df.shape: (1168, 25)
# find_continuous: len(continuous_df): 43
# create_sequence_data: X shape: (75, 6, 24), y shape: (75,)
# create_sequence_data: X shape: (5, 6, 24), y shape: (5,)
# create_sequence_data: X shape: (64, 6, 24), y shape: (64,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (6, 6, 24), y shape: (6,)
# create_sequence_data: X shape: (5, 6, 24), y shape: (5,)
# create_sequence_data: X shape: (10, 6, 24), y shape: (10,)
# create_sequence_data: X shape: (8, 6, 24), y shape: (8,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (36, 6, 24), y shape: (36,)
# create_sequence_data: X shape: (41, 6, 24), y shape: (41,)
# create_sequence_data: X shape: (14, 6, 24), y shape: (14,)
# create_sequence_data: X shape: (3, 6, 24), y shape: (3,)
# create_sequence_data: X shape: (27, 6, 24), y shape: (27,)
# create_sequence_data: X shape: (24, 6, 24), y shape: (24,)
# create_sequence_data: X shape: (15, 6, 24), y shape: (15,)
# create_sequence_data: X shape: (73, 6, 24), y shape: (73,)
# create_sequence_data: X shape: (345, 6, 24), y shape: (345,)
# create_sequence_data: X shape: (58, 6, 24), y shape: (58,)
# create_sequence_data: X shape: (30, 6, 24), y shape: (30,)
# create_sequence_data: X shape: (18, 6, 24), y shape: (18,)
# create_sequence_data: X shape: (18, 6, 24), y shape: (18,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (63, 6, 24), y shape: (63,)
# get_data: final_X shape: (971, 6, 24), final_y shape: (971,)
# X: (971, 6, 24), y: (971,)
# df.shape: (1166, 25)
# find_continuous: len(continuous_df): 42
# create_sequence_data: X shape: (75, 6, 24), y shape: (75,)
# create_sequence_data: X shape: (5, 6, 24), y shape: (5,)
# create_sequence_data: X shape: (64, 6, 24), y shape: (64,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (6, 6, 24), y shape: (6,)
# create_sequence_data: X shape: (5, 6, 24), y shape: (5,)
# create_sequence_data: X shape: (10, 6, 24), y shape: (10,)
# create_sequence_data: X shape: (8, 6, 24), y shape: (8,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (36, 6, 24), y shape: (36,)
# create_sequence_data: X shape: (41, 6, 24), y shape: (41,)
# create_sequence_data: X shape: (14, 6, 24), y shape: (14,)
# create_sequence_data: X shape: (3, 6, 24), y shape: (3,)
# create_sequence_data: X shape: (27, 6, 24), y shape: (27,)
# create_sequence_data: X shape: (23, 6, 24), y shape: (23,)
# create_sequence_data: X shape: (15, 6, 24), y shape: (15,)
# create_sequence_data: X shape: (74, 6, 24), y shape: (74,)
# create_sequence_data: X shape: (344, 6, 24), y shape: (344,)
# create_sequence_data: X shape: (58, 6, 24), y shape: (58,)
# create_sequence_data: X shape: (30, 6, 24), y shape: (30,)
# create_sequence_data: X shape: (18, 6, 24), y shape: (18,)
# create_sequence_data: X shape: (18, 6, 24), y shape: (18,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (63, 6, 24), y shape: (63,)
# get_data: final_X shape: (970, 6, 24), final_y shape: (970,)
# X: (970, 6, 24), y: (970,)
# df.shape: (1022, 25)
# find_continuous: len(continuous_df): 101
# create_sequence_data: X shape: (3, 6, 24), y shape: (3,)
# create_sequence_data: X shape: (6, 6, 24), y shape: (6,)
# create_sequence_data: X shape: (3, 6, 24), y shape: (3,)
# create_sequence_data: X shape: (3, 6, 24), y shape: (3,)
# create_sequence_data: X shape: (10, 6, 24), y shape: (10,)
# create_sequence_data: X shape: (2, 6, 24), y shape: (2,)
# create_sequence_data: X shape: (2, 6, 24), y shape: (2,)
# create_sequence_data: X shape: (5, 6, 24), y shape: (5,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (21, 6, 24), y shape: (21,)
# create_sequence_data: X shape: (73, 6, 24), y shape: (73,)
# create_sequence_data: X shape: (345, 6, 24), y shape: (345,)
# create_sequence_data: X shape: (58, 6, 24), y shape: (58,)
# create_sequence_data: X shape: (32, 6, 24), y shape: (32,)
# create_sequence_data: X shape: (15, 6, 24), y shape: (15,)
# create_sequence_data: X shape: (18, 6, 24), y shape: (18,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (65, 6, 24), y shape: (65,)
# get_data: final_X shape: (683, 6, 24), final_y shape: (683,)
# X: (683, 6, 24), y: (683,)
# df.shape: (1004, 25)
# find_continuous: len(continuous_df): 108
# create_sequence_data: X shape: (3, 6, 24), y shape: (3,)
# create_sequence_data: X shape: (6, 6, 24), y shape: (6,)
# create_sequence_data: X shape: (3, 6, 24), y shape: (3,)
# create_sequence_data: X shape: (5, 6, 24), y shape: (5,)
# create_sequence_data: X shape: (2, 6, 24), y shape: (2,)
# create_sequence_data: X shape: (5, 6, 24), y shape: (5,)
# create_sequence_data: X shape: (7, 6, 24), y shape: (7,)
# create_sequence_data: X shape: (21, 6, 24), y shape: (21,)
# create_sequence_data: X shape: (73, 6, 24), y shape: (73,)
# create_sequence_data: X shape: (82, 6, 24), y shape: (82,)
# create_sequence_data: X shape: (255, 6, 24), y shape: (255,)
# create_sequence_data: X shape: (58, 6, 24), y shape: (58,)
# create_sequence_data: X shape: (57, 6, 24), y shape: (57,)
# create_sequence_data: X shape: (18, 6, 24), y shape: (18,)
# create_sequence_data: X shape: (11, 6, 24), y shape: (11,)
# create_sequence_data: X shape: (65, 6, 24), y shape: (65,)
# get_data: final_X shape: (671, 6, 24), final_y shape: (671,)
# X: (671, 6, 24), y: (671,)

# %%
for i in range(N_CLUSTERS):
	print(f"Cluster {i}")
	print(f"April: {april_dataset[i][0].shape}, {april_dataset[i][1].shape}")
	print(f"October: {october_dataset[i][0].shape}, {october_dataset[i][1].shape}")
# Out:
# Cluster 0
# April: (45977, 6, 23), (45977,)
# October: (55369, 6, 24), (55369,)
# Cluster 1
# April: (32104, 6, 23), (32104,)
# October: (38267, 6, 24), (38267,)
# Cluster 2
# April: (40560, 6, 23), (40560,)
# October: (53980, 6, 24), (53980,)
# Cluster 3
# April: (84107, 6, 23), (84107,)
# October: (77277, 6, 24), (77277,)

# %% [markdown]
# ## Create Classification Dataset

# %%
april_classification_dataset = []
october_classification_dataset = []
for i in range(N_CLUSTERS):
	april_X, april_y = april_dataset[i]
	october_X, october_y = october_dataset[i]
	# Use last lag of the sequence as input
	april_X_last = april_X[:, -1, :]
	october_X_last = october_X[:, -1, :]
	print(f"April: {april_X_last.shape}, {april_y.shape}")
	print(f"October: {october_X_last.shape}, {october_y.shape}")
	april_Y_rain = np.array([0 if rain_level(y) == "No rain" else 1 for y in april_y])
	october_Y_rain = np.array([0 if rain_level(y) == "No rain" else 1 for y in october_y])
	april_classification_dataset.append([april_X_last, april_Y_rain])
	october_classification_dataset.append([october_X_last, october_Y_rain])
# Out:
# April: (45977, 23), (45977,)
# October: (55369, 24), (55369,)
# April: (32104, 23), (32104,)
# October: (38267, 24), (38267,)
# April: (40560, 23), (40560,)
# October: (53980, 24), (53980,)
# April: (84107, 23), (84107,)
# October: (77277, 24), (77277,)

# %%
# Count rainy days in each cluster
april_rainy_days = []
october_rainy_days = []
for i in range (N_CLUSTERS):
	april_cluster_rainy_days = np.sum(april_classification_dataset[i][1])
	october_cluster_rainy_days = np.sum(october_classification_dataset[i][1])
	april_rainy_days.append(april_cluster_rainy_days)
	october_rainy_days.append(october_cluster_rainy_days)
	print(f"Cluster {i}: April: {april_cluster_rainy_days}, October: {october_cluster_rainy_days}")
# Out:
# Cluster 0: April: 3312, October: 9677
# Cluster 1: April: 2333, October: 14640
# Cluster 2: April: 2254, October: 11253
# Cluster 3: April: 5471, October: 8248

# %% [markdown]
# ### SMOTE-ENN for imbalance data

# %%
from imblearn.combine import SMOTEENN

# Apply SMOTEENN to balance the dataset
april_resampled_classification_dataset = []
october_resampled_classification_dataset = []

for i in range(N_CLUSTERS):
	april_X, april_Y = april_classification_dataset[i]
	october_X, october_Y = october_classification_dataset[i]
	smote_enn = SMOTEENN(random_state=42)
	april_X_resampled, april_Y_resampled = smote_enn.fit_resample(april_X, april_Y)
	october_X_resampled, october_Y_resampled = smote_enn.fit_resample(october_X, october_Y)
	april_resampled_classification_dataset.append([april_X_resampled, april_Y_resampled])
	october_resampled_classification_dataset.append([october_X_resampled, october_Y_resampled])

# %%
# Count rainy days in each cluster after resampling
april_resampled_rainy_days = []
october_resampled_rainy_days = []

for i in range(N_CLUSTERS):
	april_cluster_rainy_days = np.sum(april_resampled_classification_dataset[i][1])
	october_cluster_rainy_days = np.sum(october_resampled_classification_dataset[i][1])
	april_resampled_rainy_days.append(april_cluster_rainy_days)
	october_resampled_rainy_days.append(october_cluster_rainy_days)
	print(f"Cluster {i}: April: {april_cluster_rainy_days}, October: {october_cluster_rainy_days}")
	print(f"Cluster {i}: April: {april_resampled_classification_dataset[i][0].shape}, {april_resampled_classification_dataset[i][1].shape}")
# Out:
# Cluster 0: April: 39159, October: 41819
# Cluster 0: April: (75115, 23), (75115,)
# Cluster 1: April: 27103, October: 18533
# Cluster 1: April: (51284, 23), (51284,)
# Cluster 2: April: 35492, October: 37084
# Cluster 2: April: (67673, 23), (67673,)
# Cluster 3: April: 73381, October: 64874
# Cluster 3: April: (143545, 23), (143545,)

# %%
# Decllare train and test ratio
TRAIN_RATIO = 0.8
TEST_RATIO = 1 - TRAIN_RATIO

from sklearn.model_selection import train_test_split

# Split the dataset into train and test set
april_train_X = []
april_train_Y = []
april_test_X = []
april_test_Y = []

october_train_X = []
october_train_Y = []
october_test_X = []
october_test_Y = []

for i in range(N_CLUSTERS):
	april_X, april_Y = april_resampled_classification_dataset[i]
	october_X, october_Y = october_resampled_classification_dataset[i]
	
	# Split April dataset
	april_X_train, april_X_test, april_Y_train, april_Y_test = train_test_split(april_X, april_Y, test_size=TEST_RATIO, random_state=42)
	april_train_X.append(april_X_train)
	april_train_Y.append(april_Y_train)
	april_test_X.append(april_X_test)
	april_test_Y.append(april_Y_test)
	# Split October dataset
	october_X_train, october_X_test, october_Y_train, october_Y_test = train_test_split(october_X, october_Y, test_size=TEST_RATIO, random_state=42)
	october_train_X.append(october_X_train)
	october_train_Y.append(october_Y_train)
	october_test_X.append(october_X_test)
	october_test_Y.append(october_Y_test)

# %%
# Use RandomForestClassifier to train the model
from sklearn.ensemble import RandomForestClassifier

# Train the model
april_models = []
october_models = []

for i in range(N_CLUSTERS):
	april_X_train = april_train_X[i]
	april_Y_train = april_train_Y[i]
	october_X_train = october_train_X[i]
	october_Y_train = october_train_Y[i]

	april_model = RandomForestClassifier(
		n_estimators=500, max_depth=10, random_state=42)
	october_model = RandomForestClassifier(
		n_estimators=500, max_depth=10, random_state=42)

	april_model.fit(april_X_train, april_Y_train)
	october_model.fit(october_X_train, october_Y_train)

	april_models.append(april_model)
	october_models.append(october_model)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score

# Evaluate the model
april_train_scores = []
april_test_scores = []
october_train_scores = []
october_test_scores = []

def evaluate_model(model, X_train, Y_train, X_test, Y_test):
	train_pred = model.predict(X_train)
	test_pred = model.predict(X_test)
	
	train_score = accuracy_score(Y_train, train_pred)
	test_score = accuracy_score(Y_test, test_pred)
	
	print(f"Train Accuracy: {train_score}")
	print(f"Test Accuracy: {test_score}")
	print(f"Train F1 Score: {f1_score(Y_train, train_pred)}")
	print(f"Test F1 Score: {f1_score(Y_test, test_pred)}")
	print(f"Train Confusion Matrix:")
	print(confusion_matrix(Y_train, train_pred))
	print(f"Test Confusion Matrix:")
	print(confusion_matrix(Y_test, test_pred))
	
	return train_score, test_score

for i in range(N_CLUSTERS):
	print(f"Cluster {i}")
	
	april_model = april_models[i]
	october_model = october_models[i]

	april_X_train = april_train_X[i]
	april_Y_train = april_train_Y[i]
	april_X_test = april_test_X[i]
	april_Y_test = april_test_Y[i]

	october_X_train = october_train_X[i]
	october_Y_train = october_train_Y[i]
	october_X_test = october_test_X[i]
	october_Y_test = october_test_Y[i]

	april_train_score, april_test_score = evaluate_model(april_model, april_X_train, april_Y_train, april_X_test, april_Y_test)
	october_train_score, october_test_score = evaluate_model(october_model, october_X_train, october_Y_train, october_X_test, october_Y_test)

	april_train_scores.append(april_train_score)
	april_test_scores.append(april_test_score)
	october_train_scores.append(october_train_score)
	october_test_scores.append(october_test_score)
# Out:
# Cluster 0
# Train Accuracy: 0.9530719563336217
# Test Accuracy: 0.9430872661918391
# Train F1 Score: 0.9548626672642294
# Test F1 Score: 0.9452239092831058
# Train Confusion Matrix:
# [[27444  1310]
#  [ 1510 29828]]
# Test Confusion Matrix:
# [[6791  411]
#  [ 444 7377]]
# Train Accuracy: 0.9778949315575287
# Test Accuracy: 0.9712048341349119
# Train F1 Score: 0.9784522915101428
# Test F1 Score: 0.9719872833063403
# Train Confusion Matrix:
# [[30880   549]
#  [  885 32558]]
# Test Confusion Matrix:
# [[7649  193]
#  [ 274 8102]]
# Cluster 1
# Train Accuracy: 0.9519340921831965
# Test Accuracy: 0.943648240226187
# Train F1 Score: 0.9539144659967282
# Test F1 Score: 0.9463024897807506
# Train Confusion Matrix:
# [[18646   720]
#  [ 1252 20409]]
# Test Confusion Matrix:
# [[4586  229]
#  [ 349 5093]]
# Train Accuracy: 0.9848009650180941
# Test Accuracy: 0.974496829335539
# Train F1 Score: 0.9851289833080424
# Test F1 Score: 0.9749830966869506
# Train Confusion Matrix:
# [[13967   209]
#  [  232 14607]]
# Test Confusion Matrix:
# [[3464   96]
#  [  89 3605]]
# Cluster 2
# Train Accuracy: 0.9443828733976135
# Test Accuracy: 0.93852973771703
# Train F1 Score: 0.9469193477302776
# Test F1 Score: 0.9417366946778711
# Train Confusion Matrix:
# [[24270  1533]
#  [ 1478 26857]]
# Test Confusion Matrix:
# [[5979  399]
#  [ 433 6724]]
# Train Accuracy: 0.9732944462989968
# Test Accuracy: 0.9643007730147576
# Train F1 Score: 0.9742346679323322
# Test F1 Score: 0.9653667848377421
# Train Confusion Matrix:
# [[26660   546]
#  [  974 28737]]
# Test Confusion Matrix:
# [[6642  215]
#  [ 293 7080]]
# Cluster 3
# Train Accuracy: 0.9532289525932635
# Test Accuracy: 0.9509213138736982
# Train F1 Score: 0.9545781288320211
# Test F1 Score: 0.9520829790851896
# Train Confusion Matrix:
# [[53027  3030]
#  [ 2341 56438]]
# Test Confusion Matrix:
# [[13302   805]
#  [  604 13998]]
# Train Accuracy: 0.971996781467611
# Test Accuracy: 0.9644772916915008
# Train F1 Score: 0.9727350981207625
# Test F1 Score: 0.965230242688239
# Train Confusion Matrix:
# [[47561  1155]
#  [ 1664 50287]]
# Test Confusion Matrix:
# [[11864   380]
#  [  514 12409]]

# %% [markdown]
# # Regression model

# %%
import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.metrics import *
from tensorflow.keras.optimizers import *


# https://www.mdpi.com/2673-4931/26/1/157?fbclid=IwY2xjawGWk1ZleHRuA2FlbQIxMAABHXeG02cvdL_VkwkQN1k0bjHUELuh8WNcvaYEVeYGaaVkXOcJScoPzoelNQ_aem_l-J1k44v7FzjKOOUZ0twTA
def create_lstm_model(time_step, no_features):
    """one hidden layer with 100 nodes and is trained with a learning rate of 9 × 10−5"""
    model = tf.keras.Sequential([
        tf.keras.layers.InputLayer(input_shape=(time_step, no_features)),
        tf.keras.layers.LSTM(128, activation='relu', return_sequences=True),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.LSTM(128, activation='relu', return_sequences=True),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.LSTM(256, activation='relu', return_sequences=True),
        tf.keras.layers.Dropout(0.4),
        tf.keras.layers.LSTM(256, activation='relu', return_sequences=False),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(1)
    ])
    return model
# Out:
# 2024-11-05 18:24:46.523631: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-05 18:24:46.548041: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-05 18:24:46.555294: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-05 18:24:47.934932: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
regression_april_dataset = []
regression_october_dataset = []
for i in range(N_CLUSTERS):
	april_X, april_Y = april_dataset[i]
	october_X, october_Y = october_dataset[i]
	print(f"Cluster{i}")
	print(f"April: {april_X.shape}, {april_Y.shape}")
	print(f"October: {october_X.shape}, {october_Y.shape}")
	print("=" * 50)
	acd_X = []
	acd_Y = []
	ocd_X = []
	ocd_Y = []
	for j in range(april_Y.shape[0]):
		if rain_level(april_Y[j]) != "No rain":
			acd_X.append(april_X[j])
			acd_Y.append(april_Y[j])
	for j in range(october_Y.shape[0]):
		if rain_level(october_Y[j]) != "No rain":
			ocd_X.append(october_X[j])
			ocd_Y.append(october_Y[j])
	acd_X = np.array(acd_X)
	acd_Y = np.array(acd_Y)
	ocd_X = np.array(ocd_X)
	ocd_Y = np.array(ocd_Y)
	regression_april_dataset.append([acd_X, acd_Y])
	regression_october_dataset.append([ocd_X, ocd_Y])
# Out:
# Cluster0
# April: (45977, 6, 23), (45977,)
# October: (55369, 6, 24), (55369,)
# ==================================================
# Cluster1
# April: (32104, 6, 23), (32104,)
# October: (38267, 6, 24), (38267,)
# ==================================================
# Cluster2
# April: (40560, 6, 23), (40560,)
# October: (53980, 6, 24), (53980,)
# ==================================================
# Cluster3
# April: (84107, 6, 23), (84107,)
# October: (77277, 6, 24), (77277,)
# ==================================================

# %%
from sklearn.preprocessing import MinMaxScaler

def scale_train(X_train, X_test):
	scaler = MinMaxScaler()
	X_train_scaled = scaler.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
	X_test_scaled = scaler.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)
	return X_train_scaled, X_test_scaled



regression_april_dataset_train_X = []
regression_april_dataset_train_Y = []
regression_april_dataset_test_X = []
regression_april_dataset_test_Y = []

regression_october_dataset_train_X = []
regression_october_dataset_train_Y = []
regression_october_dataset_test_X = []
regression_october_dataset_test_Y = []

for i in range(N_CLUSTERS):
	regression_april_X, regression_april_Y = regression_april_dataset[i]
	regression_october_X, regression_october_Y = regression_october_dataset[i]

	# Split April dataset
	regression_april_X_train, regression_april_X_test, regression_april_Y_train, regression_april_Y_test = train_test_split(regression_april_X, regression_april_Y, test_size=TEST_RATIO, random_state=42)
	regression_april_X_train, regression_april_X_test = scale_train(regression_april_X_train, regression_april_X_test)
	regression_april_dataset_train_X.append(regression_april_X_train)
	regression_april_dataset_train_Y.append(regression_april_Y_train)
	regression_april_dataset_test_X.append(regression_april_X_test)
	regression_april_dataset_test_Y.append(regression_april_Y_test)
	# Split October dataset
	regression_october_X_train, regression_october_X_test, regression_october_Y_train, regression_october_Y_test = train_test_split(regression_october_X, regression_october_Y, test_size=TEST_RATIO, random_state=42)
	regression_october_X_train, regression_october_X_test = scale_train(regression_october_X_train, regression_october_X_test)
	regression_october_dataset_train_X.append(regression_october_X_train)
	regression_october_dataset_train_Y.append(regression_october_Y_train)
	regression_october_dataset_test_X.append(regression_october_X_test)
	regression_october_dataset_test_Y.append(regression_october_Y_test)
	print(f"Cluster {i}")
	print(f"April: {regression_april_X_train.shape}, {regression_april_Y_train.shape}")
	print(f"October: {regression_october_X_train.shape}, {regression_october_Y_train.shape}")
# Out:
# Cluster 0
# April: (2649, 6, 23), (2649,)
# October: (7741, 6, 24), (7741,)
# Cluster 1
# April: (1866, 6, 23), (1866,)
# October: (11712, 6, 24), (11712,)
# Cluster 2
# April: (1803, 6, 23), (1803,)
# October: (9002, 6, 24), (9002,)
# Cluster 3
# April: (4376, 6, 23), (4376,)
# October: (6598, 6, 24), (6598,)

# %%
# Train model
regression_april_models = []
regression_october_models = []


for i in range(N_CLUSTERS):
	april_X_train = regression_april_dataset_train_X[i]
	april_Y_train = regression_april_dataset_train_Y[i]
	october_X_train = regression_october_dataset_train_X[i]
	october_Y_train = regression_october_dataset_train_Y[i]
	april_model = create_lstm_model(TIME_STEP, april_X_train.shape[-1])
	october_model = create_lstm_model(TIME_STEP, october_X_train.shape[-1])
	april_model.compile(optimizer=AdamW(learning_rate=9e-5), loss='mse', metrics=['mae'])
	october_model.compile(optimizer=AdamW(learning_rate=9e-5), loss='mse', metrics=['mae'])
	april_model.fit(april_X_train, april_Y_train, epochs=100, batch_size=32)
	october_model.fit(october_X_train, october_Y_train, epochs=100, batch_size=32)
	regression_april_models.append(april_model)
	regression_october_models.append(october_model)
# Out:
# /home/hoangbaoan1901/anaconda3/envs/tf-env/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730805889.117715  140707 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730805889.155269  140707 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730805889.155574  140707 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730805889.161390  140707 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730805889.161687  140707 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730805889.161913  140707 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730805889.339333  140707 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730805889.339613  140707 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730805889.339840  140707 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-05 18:24:49.339993: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5167 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1060 6GB, pci bus id: 0000:03:00.0, compute capability: 6.1
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730805896.658745  141305 service.cc:146] XLA service 0x6ec8f160 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1730805896.658805  141305 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce GTX 1060 6GB, Compute Capability 6.1
# 2024-11-05 18:24:56.820093: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-05 18:24:57.830803: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 11/83 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 23.0137 - mae: 1.8989
# I0000 00:00:1730805903.395180  141305 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 20s 92ms/step - loss: 17.4127 - mae: 1.7641
# Epoch 2/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 12.4386 - mae: 1.9436
# Epoch 3/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 11.1278 - mae: 1.9027
# Epoch 4/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 12.3962 - mae: 1.8795
# Epoch 5/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 11.7662 - mae: 1.9257
# Epoch 6/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 10.6677 - mae: 1.8787
# Epoch 7/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 11.9737 - mae: 1.8001
# Epoch 8/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 12.2682 - mae: 2.0695
# Epoch 9/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 12.3387 - mae: 1.9581
# Epoch 10/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 12.2482 - mae: 1.9512
# Epoch 11/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 13.2861 - mae: 2.0142
# Epoch 12/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 10.7718 - mae: 1.8892
# Epoch 13/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 10.2253 - mae: 1.7712
# Epoch 14/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 10.8666 - mae: 1.7916
# Epoch 15/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.3921 - mae: 1.7091
# Epoch 16/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 12.1159 - mae: 1.9252
# Epoch 17/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 10.5038 - mae: 1.7521
# Epoch 18/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 10.9047 - mae: 1.7859
# Epoch 19/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.6676 - mae: 1.7201
# Epoch 20/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 10.8583 - mae: 1.6671
# Epoch 21/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 10.0515 - mae: 1.7218
# Epoch 22/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 10.4836 - mae: 1.8295
# Epoch 23/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 11.3761 - mae: 1.7710
# Epoch 24/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.8934 - mae: 1.6457
# Epoch 25/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.9306 - mae: 1.5758
# Epoch 26/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.9994 - mae: 1.5892
# Epoch 27/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.9673 - mae: 1.7036
# Epoch 28/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 11.6371 - mae: 1.7355
# Epoch 29/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 11.3018 - mae: 1.7914
# Epoch 30/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.6693 - mae: 1.6820
# Epoch 31/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.7828 - mae: 1.6714
# Epoch 32/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.2380 - mae: 1.6440
# Epoch 33/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 12.3956 - mae: 1.7295
# Epoch 34/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 10.1857 - mae: 1.6617
# Epoch 35/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.7632 - mae: 1.6564
# Epoch 36/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 10.1132 - mae: 1.6344
# Epoch 37/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.7799 - mae: 1.6596
# Epoch 38/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 11.3527 - mae: 1.7902
# Epoch 39/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 11.8108 - mae: 1.6739
# Epoch 40/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.9895 - mae: 1.6143
# Epoch 41/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 11.4442 - mae: 1.6680
# Epoch 42/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 10.3625 - mae: 1.7103
# Epoch 43/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.8497 - mae: 1.6750
# Epoch 44/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.8923 - mae: 1.6237
# Epoch 45/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 10.6194 - mae: 1.6928
# Epoch 46/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 10.9858 - mae: 1.5939
# Epoch 47/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.1649 - mae: 1.5233
# Epoch 48/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 11.6454 - mae: 1.6630
# Epoch 49/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 11.1670 - mae: 1.7135
# Epoch 50/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.4874 - mae: 1.5801
# Epoch 51/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.3174 - mae: 1.5830
# Epoch 52/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.9703 - mae: 1.6153
# Epoch 53/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 10.7646 - mae: 1.6556
# Epoch 54/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.3302 - mae: 1.5937
# Epoch 55/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 10.8284 - mae: 1.6037
# Epoch 56/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.6805 - mae: 1.6022
# Epoch 57/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.1960 - mae: 1.5967
# Epoch 58/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 10.6296 - mae: 1.5419
# Epoch 59/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.2689 - mae: 1.5811
# Epoch 60/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 11.6800 - mae: 1.6307
# Epoch 61/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.4212 - mae: 1.5003
# Epoch 62/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.8996 - mae: 1.6113
# Epoch 63/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.2037 - mae: 1.5251
# Epoch 64/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.6302 - mae: 1.4826
# Epoch 65/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.7365 - mae: 1.5241
# Epoch 66/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.6087 - mae: 1.5228
# Epoch 67/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.3809 - mae: 1.4824
# Epoch 68/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.0650 - mae: 1.5193
# Epoch 69/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.6134 - mae: 1.5616
# Epoch 70/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.6024 - mae: 1.5240
# Epoch 71/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 11.7507 - mae: 1.6786
# Epoch 72/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.3968 - mae: 1.5423
# Epoch 73/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 10.7536 - mae: 1.6486
# Epoch 74/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.8474 - mae: 1.5617
# Epoch 75/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.1041 - mae: 1.4675
# Epoch 76/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.7519 - mae: 1.6171
# Epoch 77/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.1764 - mae: 1.5347
# Epoch 78/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.9834 - mae: 1.5649
# Epoch 79/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.0334 - mae: 1.4575
# Epoch 80/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.5308 - mae: 1.5482
# Epoch 81/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 10.5480 - mae: 1.6167
# Epoch 82/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 10.6439 - mae: 1.5675
# Epoch 83/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.3283 - mae: 1.3787
# Epoch 84/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 10.3724 - mae: 1.6303
# Epoch 85/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.8830 - mae: 1.4733
# Epoch 86/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.5460 - mae: 1.5729
# Epoch 87/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 10.3144 - mae: 1.6100
# Epoch 88/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 10.0211 - mae: 1.6231
# Epoch 89/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.1837 - mae: 1.5470
# Epoch 90/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.0220 - mae: 1.4877
# Epoch 91/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.4736 - mae: 1.5277
# Epoch 92/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.1855 - mae: 1.5155
# Epoch 93/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.6321 - mae: 1.5714
# Epoch 94/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.6509 - mae: 1.5710
# Epoch 95/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 10.1763 - mae: 1.5108
# Epoch 96/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.0363 - mae: 1.5072
# Epoch 97/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 10.6770 - mae: 1.6360
# Epoch 98/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 10.9978 - mae: 1.6068
# Epoch 99/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.4200 - mae: 1.4804
# Epoch 100/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.6790 - mae: 1.5651
# Epoch 1/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 21s 38ms/step - loss: 15.0517 - mae: 2.0664
# Epoch 2/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 11.1147 - mae: 1.8434
# Epoch 3/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 11.0961 - mae: 1.7991
# Epoch 4/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 9.1829 - mae: 1.6927
# Epoch 5/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 8.0139 - mae: 1.6327
# Epoch 6/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 8.9392 - mae: 1.5836
# Epoch 7/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 8.2953 - mae: 1.5691
# Epoch 8/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 8.1300 - mae: 1.5624
# Epoch 9/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 8.0924 - mae: 1.5204
# Epoch 10/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 9.1770 - mae: 1.5820
# Epoch 11/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 7.6095 - mae: 1.5300
# Epoch 12/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 7.8508 - mae: 1.5388
# Epoch 13/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 7.9666 - mae: 1.4716
# Epoch 14/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 6.6580 - mae: 1.4438
# Epoch 15/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 7.3352 - mae: 1.4312
# Epoch 16/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 7.7906 - mae: 1.4575
# Epoch 17/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 7.4856 - mae: 1.4814
# Epoch 18/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 7.6083 - mae: 1.4972
# Epoch 19/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 7.6470 - mae: 1.4875
# Epoch 20/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 7.1173 - mae: 1.4543
# Epoch 21/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 8.5497 - mae: 1.5151
# Epoch 22/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 6.6358 - mae: 1.4236
# Epoch 23/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 6.9153 - mae: 1.4372
# Epoch 24/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 6.3403 - mae: 1.3767
# Epoch 25/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 7.1697 - mae: 1.4357
# Epoch 26/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 7.0037 - mae: 1.4178
# Epoch 27/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 7.5703 - mae: 1.4416
# Epoch 28/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 6.5363 - mae: 1.4033
# Epoch 29/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 6.5670 - mae: 1.3923
# Epoch 30/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 6.1167 - mae: 1.3592
# Epoch 31/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 6.4945 - mae: 1.3704
# Epoch 32/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 6.3526 - mae: 1.3811
# Epoch 33/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 7.1765 - mae: 1.3583
# Epoch 34/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 6.6725 - mae: 1.3721
# Epoch 35/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 7.5579 - mae: 1.4389
# Epoch 36/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 6.3604 - mae: 1.3546
# Epoch 37/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 6.4115 - mae: 1.3396
# Epoch 38/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.9880 - mae: 1.3492
# Epoch 39/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 6.8806 - mae: 1.4071
# Epoch 40/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.6042 - mae: 1.3262
# Epoch 41/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 6.7144 - mae: 1.3524
# Epoch 42/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.6908 - mae: 1.3262
# Epoch 43/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 6.2412 - mae: 1.3374
# Epoch 44/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 6.1528 - mae: 1.3311
# Epoch 45/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 7.2253 - mae: 1.3615
# Epoch 46/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 6.9143 - mae: 1.3783
# Epoch 47/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 6.1826 - mae: 1.3199
# Epoch 48/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.6888 - mae: 1.2953
# Epoch 49/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 6.0214 - mae: 1.2905
# Epoch 50/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 6.2107 - mae: 1.3181
# Epoch 51/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 6.0865 - mae: 1.3104
# Epoch 52/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 7.2388 - mae: 1.3460
# Epoch 53/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 6.0149 - mae: 1.3185
# Epoch 54/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 6.3175 - mae: 1.2923
# Epoch 55/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 4.8507 - mae: 1.2439
# Epoch 56/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 5.0927 - mae: 1.2357
# Epoch 57/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 5.6070 - mae: 1.2855
# Epoch 58/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 5.3725 - mae: 1.2464
# Epoch 59/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 5.1906 - mae: 1.2369
# Epoch 60/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 5.2402 - mae: 1.2631
# Epoch 61/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.5784 - mae: 1.2616
# Epoch 62/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 4.7345 - mae: 1.2050
# Epoch 63/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 4.9822 - mae: 1.2265
# Epoch 64/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 5.0883 - mae: 1.2761
# Epoch 65/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 4.8293 - mae: 1.2325
# Epoch 66/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 6.8133 - mae: 1.3241
# Epoch 67/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.3435 - mae: 1.2369
# Epoch 68/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.1742 - mae: 1.2824
# Epoch 69/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.6983 - mae: 1.2998
# Epoch 70/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.5459 - mae: 1.3121
# Epoch 71/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.2362 - mae: 1.2596
# Epoch 72/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.5624 - mae: 1.2594
# Epoch 73/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.9336 - mae: 1.2698
# Epoch 74/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.3761 - mae: 1.2588
# Epoch 75/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.8595 - mae: 1.2765
# Epoch 76/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 4.5490 - mae: 1.2122
# Epoch 77/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.1226 - mae: 1.2383
# Epoch 78/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.3661 - mae: 1.2455
# Epoch 79/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.7016 - mae: 1.2233
# Epoch 80/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.5663 - mae: 1.2723
# Epoch 81/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.3588 - mae: 1.2216
# Epoch 82/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 4.9680 - mae: 1.2128
# Epoch 83/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 4.7860 - mae: 1.2018
# Epoch 84/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 5.7176 - mae: 1.2389
# Epoch 85/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.1566 - mae: 1.2508
# Epoch 86/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 5.7203 - mae: 1.2275
# Epoch 87/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 4.7747 - mae: 1.1917
# Epoch 88/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 4.8303 - mae: 1.2013
# Epoch 89/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 4.4088 - mae: 1.1731
# Epoch 90/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.0691 - mae: 1.2122
# Epoch 91/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 4.3194 - mae: 1.1732
# Epoch 92/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 4.9361 - mae: 1.2437
# Epoch 93/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 4.6668 - mae: 1.2015
# Epoch 94/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 5.4334 - mae: 1.2355
# Epoch 95/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 6.4347 - mae: 1.2396
# Epoch 96/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.0703 - mae: 1.2054
# Epoch 97/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 4.7798 - mae: 1.2319
# Epoch 98/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.4216 - mae: 1.2513
# Epoch 99/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.3766 - mae: 1.2005
# Epoch 100/100
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 4.8127 - mae: 1.2145
# Epoch 1/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 19s 123ms/step - loss: 26.3424 - mae: 1.7907
# Epoch 2/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 20.4952 - mae: 1.6584
# Epoch 3/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 27.8945 - mae: 2.3947
# Epoch 4/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 30.1350 - mae: 2.2164
# Epoch 5/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 27.6853 - mae: 2.1079
# Epoch 6/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 33.1951 - mae: 2.2426
# Epoch 7/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 30.7421 - mae: 2.3674
# Epoch 8/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 25.4104 - mae: 2.1576
# Epoch 9/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 38.1212 - mae: 2.5693
# Epoch 10/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 28.9829 - mae: 2.2432
# Epoch 11/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 29.7631 - mae: 2.1186
# Epoch 12/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 22.5230 - mae: 2.2970
# Epoch 13/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 24.3643 - mae: 1.9114
# Epoch 14/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 29.1458 - mae: 2.2647
# Epoch 15/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 25.6747 - mae: 1.9956
# Epoch 16/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 23.1296 - mae: 2.2494
# Epoch 17/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 23.2910 - mae: 2.1657
# Epoch 18/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 18.9160 - mae: 1.8451
# Epoch 19/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 26.9192 - mae: 2.2822
# Epoch 20/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 29.4302 - mae: 2.2385
# Epoch 21/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 23.2866 - mae: 2.1293
# Epoch 22/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 16.2519 - mae: 1.7855
# Epoch 23/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 17.4502 - mae: 1.9469
# Epoch 24/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 23.2266 - mae: 2.0529
# Epoch 25/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 22.3049 - mae: 1.8243
# Epoch 26/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 32.1251 - mae: 2.3831
# Epoch 27/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 25.7859 - mae: 1.9596
# Epoch 28/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 23.0238 - mae: 1.9719
# Epoch 29/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 23.7168 - mae: 2.1625
# Epoch 30/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 21.5591 - mae: 1.8800
# Epoch 31/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 29.2972 - mae: 2.1106
# Epoch 32/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 24.9479 - mae: 1.8704
# Epoch 33/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 19.4780 - mae: 1.9423
# Epoch 34/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 24.4547 - mae: 2.0506
# Epoch 35/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 16.4273 - mae: 1.9843
# Epoch 36/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 30.5303 - mae: 1.8694
# Epoch 37/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 22.0263 - mae: 1.8195
# Epoch 38/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 19.6367 - mae: 1.8077
# Epoch 39/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 20.6372 - mae: 2.0240
# Epoch 40/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 26.5837 - mae: 1.8928
# Epoch 41/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 21.6114 - mae: 1.8400
# Epoch 42/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 17.7030 - mae: 1.9717
# Epoch 43/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 23.7308 - mae: 1.9525
# Epoch 44/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 29.0630 - mae: 2.0335
# Epoch 45/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 20.5817 - mae: 2.0192
# Epoch 46/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 17.4130 - mae: 1.8623
# Epoch 47/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 19.3007 - mae: 1.9082
# Epoch 48/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 23.6925 - mae: 2.0431
# Epoch 49/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 18.1320 - mae: 1.8779
# Epoch 50/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 28.0534 - mae: 2.0678
# Epoch 51/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 24.8022 - mae: 1.9763
# Epoch 52/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 19.7235 - mae: 1.9383
# Epoch 53/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 13.5286 - mae: 1.7601
# Epoch 54/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 18.5094 - mae: 2.0358
# Epoch 55/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 20.7218 - mae: 2.0266
# Epoch 56/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 14.4494 - mae: 1.7052
# Epoch 57/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 16.5120 - mae: 1.8899
# Epoch 58/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 20.1566 - mae: 1.9299
# Epoch 59/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 15.6164 - mae: 1.7358
# Epoch 60/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 22.2064 - mae: 1.8967
# Epoch 61/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 18.1944 - mae: 1.9626
# Epoch 62/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 14.2870 - mae: 1.7258
# Epoch 63/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 10.4630 - mae: 1.5811
# Epoch 64/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 17.9278 - mae: 1.9355
# Epoch 65/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 13.6874 - mae: 1.7925
# Epoch 66/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 12.9986 - mae: 1.6398
# Epoch 67/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 16.0930 - mae: 1.8199
# Epoch 68/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 21.6175 - mae: 1.8801
# Epoch 69/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 25.9456 - mae: 1.9876
# Epoch 70/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 12.6857 - mae: 1.6675
# Epoch 71/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 14.3065 - mae: 1.6925
# Epoch 72/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 13.3113 - mae: 1.7571
# Epoch 73/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 18.7067 - mae: 1.9038
# Epoch 74/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 18.8143 - mae: 1.8304
# Epoch 75/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 15.0886 - mae: 1.6575
# Epoch 76/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 14.5366 - mae: 1.8016
# Epoch 77/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 18.7014 - mae: 1.6818
# Epoch 78/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 13.7510 - mae: 1.6371
# Epoch 79/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 19.6650 - mae: 1.8759
# Epoch 80/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 13.9589 - mae: 1.7516
# Epoch 81/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 13.9064 - mae: 1.8127
# Epoch 82/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 12.6116 - mae: 1.5606
# Epoch 83/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 19.1385 - mae: 1.7754
# Epoch 84/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 15.5335 - mae: 1.7776
# Epoch 85/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 22.2310 - mae: 2.0055
# Epoch 86/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 13.4716 - mae: 1.6282
# Epoch 87/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 14.4425 - mae: 1.8671
# Epoch 88/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 15.4797 - mae: 1.7605
# Epoch 89/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 24.6660 - mae: 1.8546
# Epoch 90/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 16.7518 - mae: 1.9325
# Epoch 91/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 19.2131 - mae: 1.8198
# Epoch 92/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 19.6191 - mae: 1.8218
# Epoch 93/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 12.9947 - mae: 1.6208
# Epoch 94/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 12.6877 - mae: 1.7542
# Epoch 95/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 20.3531 - mae: 1.9620
# Epoch 96/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 13.6530 - mae: 1.7126
# Epoch 97/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 18.9684 - mae: 1.9603
# Epoch 98/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 16.7190 - mae: 1.7421
# Epoch 99/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 16.7558 - mae: 1.8226
# Epoch 100/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 12.7592 - mae: 1.5567
# Epoch 1/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - loss: 67.8219 - mae: 4.5277
# Epoch 2/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 52.6441 - mae: 4.1764
# Epoch 3/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 48.9767 - mae: 4.1001
# Epoch 4/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 42.8795 - mae: 3.7776
# Epoch 5/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 43.0786 - mae: 3.7766
# Epoch 6/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 51.7328 - mae: 4.0401
# Epoch 7/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 44.5464 - mae: 3.7422
# Epoch 8/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 42.7068 - mae: 3.7110
# Epoch 9/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 42.7133 - mae: 3.6232
# Epoch 10/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 38.7873 - mae: 3.5470
# Epoch 11/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 37.1270 - mae: 3.4634
# Epoch 12/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 42.0937 - mae: 3.5839
# Epoch 13/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 37.7056 - mae: 3.4032
# Epoch 14/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 37.8588 - mae: 3.3690
# Epoch 15/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 41.8138 - mae: 3.4533
# Epoch 16/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 36.2315 - mae: 3.4138
# Epoch 17/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 35.4167 - mae: 3.3383
# Epoch 18/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 34.3401 - mae: 3.2889
# Epoch 19/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 35.1600 - mae: 3.3209
# Epoch 20/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 37.2314 - mae: 3.3572
# Epoch 21/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 33.3129 - mae: 3.2298
# Epoch 22/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 32.8478 - mae: 3.2067
# Epoch 23/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 29.8954 - mae: 3.1756
# Epoch 24/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 31.7151 - mae: 3.2807
# Epoch 25/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 31.3828 - mae: 3.1331
# Epoch 26/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 31.2326 - mae: 3.1981
# Epoch 27/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 27.6918 - mae: 3.0328
# Epoch 28/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 31.3040 - mae: 3.1827
# Epoch 29/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 29.1443 - mae: 3.0132
# Epoch 30/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 32.8501 - mae: 3.1796
# Epoch 31/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 29.2584 - mae: 3.0334
# Epoch 32/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 29.5531 - mae: 3.0958
# Epoch 33/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 28.8666 - mae: 2.9666
# Epoch 34/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 29.8186 - mae: 3.0571
# Epoch 35/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 29.0562 - mae: 3.0540
# Epoch 36/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 27.6509 - mae: 2.9685
# Epoch 37/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 29.0550 - mae: 3.0256
# Epoch 38/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 25.6960 - mae: 2.8759
# Epoch 39/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 25.9813 - mae: 2.9686
# Epoch 40/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 29.1421 - mae: 3.0039
# Epoch 41/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 28.2990 - mae: 3.0073
# Epoch 42/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 28.8650 - mae: 2.9861
# Epoch 43/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 29.6915 - mae: 3.0269
# Epoch 44/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 26.0156 - mae: 2.8381
# Epoch 45/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 27.5761 - mae: 2.9337
# Epoch 46/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 26.8376 - mae: 2.9330
# Epoch 47/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 26.8328 - mae: 2.8938
# Epoch 48/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 25.8417 - mae: 2.8572
# Epoch 49/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 27.0473 - mae: 2.8467
# Epoch 50/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 28.5509 - mae: 2.9601
# Epoch 51/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 24.1804 - mae: 2.7900
# Epoch 52/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 25.9983 - mae: 2.8622
# Epoch 53/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 25.9419 - mae: 2.8765
# Epoch 54/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 25.9294 - mae: 2.8227
# Epoch 55/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 26.6586 - mae: 2.9315
# Epoch 56/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 26.6670 - mae: 2.8422
# Epoch 57/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 24.5510 - mae: 2.8022
# Epoch 58/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 26.7869 - mae: 2.8930
# Epoch 59/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 24.3644 - mae: 2.8277
# Epoch 60/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 24.7007 - mae: 2.8506
# Epoch 61/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 24.0903 - mae: 2.7169
# Epoch 62/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 26.1648 - mae: 2.9047
# Epoch 63/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 24.4656 - mae: 2.8156
# Epoch 64/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 22.3453 - mae: 2.7256
# Epoch 65/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 24.2843 - mae: 2.7748
# Epoch 66/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 27.4360 - mae: 2.9098
# Epoch 67/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 26.3056 - mae: 2.8443
# Epoch 68/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 23.9852 - mae: 2.7718
# Epoch 69/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 23.4373 - mae: 2.7789
# Epoch 70/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 24.8077 - mae: 2.7912
# Epoch 71/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 23.4528 - mae: 2.7597
# Epoch 72/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 24.5640 - mae: 2.7960
# Epoch 73/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 23.9857 - mae: 2.7122
# Epoch 74/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 24.3024 - mae: 2.7590
# Epoch 75/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 21.3550 - mae: 2.6939
# Epoch 76/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 25.0848 - mae: 2.8266
# Epoch 77/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 23.7004 - mae: 2.7238
# Epoch 78/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 24.2607 - mae: 2.7659
# Epoch 79/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 24.2830 - mae: 2.7929
# Epoch 80/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 23.9837 - mae: 2.7158
# Epoch 81/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 25.4139 - mae: 2.7981
# Epoch 82/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 23.5561 - mae: 2.7202
# Epoch 83/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 23.0496 - mae: 2.7505
# Epoch 84/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 23.6629 - mae: 2.7578
# Epoch 85/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 24.5421 - mae: 2.6984
# Epoch 86/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 21.4295 - mae: 2.6619
# Epoch 87/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 24.7585 - mae: 2.8222
# Epoch 88/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 25.4746 - mae: 2.8081
# Epoch 89/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 25.6912 - mae: 2.7845
# Epoch 90/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 21.3825 - mae: 2.6396
# Epoch 91/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 23.1648 - mae: 2.7482
# Epoch 92/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 23.1047 - mae: 2.7319
# Epoch 93/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 22.1979 - mae: 2.7199
# Epoch 94/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 24.1370 - mae: 2.7293
# Epoch 95/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 22.5810 - mae: 2.7072
# Epoch 96/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 24.9628 - mae: 2.7383
# Epoch 97/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 25.2393 - mae: 2.7484
# Epoch 98/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 23.1858 - mae: 2.7122
# Epoch 99/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 22.4329 - mae: 2.7136
# Epoch 100/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 22.1339 - mae: 2.6624
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 18s 124ms/step - loss: 17.6875 - mae: 1.2160
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 18.2929 - mae: 1.3092
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 18.2808 - mae: 1.5176
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 12.6121 - mae: 1.5264
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 13.7301 - mae: 1.3817
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 13.7928 - mae: 1.5723
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 15.1492 - mae: 1.4209
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 15.9111 - mae: 1.5359
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 13.0384 - mae: 1.4700
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 10.3907 - mae: 1.4608
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.7497 - mae: 1.3576
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 12.2423 - mae: 1.3203
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 14.0925 - mae: 1.6061
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 15.7362 - mae: 1.6180
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 19.0950 - mae: 1.6666
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 23.0879 - mae: 1.4714
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 13.0761 - mae: 1.5636
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 16.3378 - mae: 1.4806
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.1714 - mae: 1.4270
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 11.8071 - mae: 1.5790
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 11.6796 - mae: 1.4929
# Epoch 22/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 17.9087 - mae: 1.4850
# Epoch 23/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 11.5917 - mae: 1.3393
# Epoch 24/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.5226 - mae: 1.2938
# Epoch 25/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 12.8733 - mae: 1.5315
# Epoch 26/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.6903 - mae: 1.3674
# Epoch 27/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 12.5332 - mae: 1.6222
# Epoch 28/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 13.3076 - mae: 1.4294
# Epoch 29/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 12.1762 - mae: 1.2718
# Epoch 30/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 12.4940 - mae: 1.4174
# Epoch 31/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 11.5765 - mae: 1.3685
# Epoch 32/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.9902 - mae: 1.3138
# Epoch 33/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 10.2153 - mae: 1.3571
# Epoch 34/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 13.1999 - mae: 1.5586
# Epoch 35/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 11.5127 - mae: 1.3644
# Epoch 36/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 15.5973 - mae: 1.5643
# Epoch 37/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 14.3175 - mae: 1.4909
# Epoch 38/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 12.5362 - mae: 1.2952
# Epoch 39/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 11.8600 - mae: 1.3206
# Epoch 40/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.8741 - mae: 1.3575
# Epoch 41/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 11.9277 - mae: 1.4213
# Epoch 42/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 14.6936 - mae: 1.3782
# Epoch 43/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 13.2130 - mae: 1.4374
# Epoch 44/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 13.5490 - mae: 1.3317
# Epoch 45/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.5191 - mae: 1.0919
# Epoch 46/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 11.5663 - mae: 1.2684
# Epoch 47/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 11.9602 - mae: 1.3931
# Epoch 48/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 10.4118 - mae: 1.5340
# Epoch 49/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 12.4306 - mae: 1.2695
# Epoch 50/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 18.3166 - mae: 1.2249
# Epoch 51/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.8154 - mae: 1.2701
# Epoch 52/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 19.3156 - mae: 1.6875
# Epoch 53/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 10.6463 - mae: 1.4278
# Epoch 54/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.6109 - mae: 1.2719
# Epoch 55/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.2749 - mae: 1.3227
# Epoch 56/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.6728 - mae: 1.2474
# Epoch 57/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 11.0817 - mae: 1.4896
# Epoch 58/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.5898 - mae: 1.2563
# Epoch 59/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 11.0789 - mae: 1.3663
# Epoch 60/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.7173 - mae: 1.2478
# Epoch 61/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.3105 - mae: 1.3683
# Epoch 62/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.7320 - mae: 1.3519
# Epoch 63/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.1820 - mae: 1.1157
# Epoch 64/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 12.2878 - mae: 1.3857
# Epoch 65/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 11.6845 - mae: 1.1864
# Epoch 66/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 15.9963 - mae: 1.6514
# Epoch 67/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 10.5277 - mae: 1.4696
# Epoch 68/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.5363 - mae: 1.2770
# Epoch 69/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.0893 - mae: 1.2153
# Epoch 70/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.2364 - mae: 1.3432
# Epoch 71/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.4191 - mae: 1.3143
# Epoch 72/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 10.2171 - mae: 1.4111
# Epoch 73/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.1368 - mae: 1.2537
# Epoch 74/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.8689 - mae: 1.3379
# Epoch 75/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.0900 - mae: 1.1216
# Epoch 76/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 14.8802 - mae: 1.6072
# Epoch 77/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.0313 - mae: 1.3139
# Epoch 78/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.2917 - mae: 1.3632
# Epoch 79/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.1546 - mae: 1.2989
# Epoch 80/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 11.4735 - mae: 1.2752
# Epoch 81/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.5329 - mae: 1.3162
# Epoch 82/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.2026 - mae: 1.2686
# Epoch 83/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.9216 - mae: 1.3139
# Epoch 84/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 12.5085 - mae: 1.1906
# Epoch 85/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 13.2178 - mae: 1.1896
# Epoch 86/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.8304 - mae: 1.4021
# Epoch 87/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.4408 - mae: 1.5141
# Epoch 88/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 10.2954 - mae: 1.4557
# Epoch 89/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.6126 - mae: 1.2343
# Epoch 90/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.4601 - mae: 1.4320
# Epoch 91/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.6825 - mae: 1.2369
# Epoch 92/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.1768 - mae: 1.3821
# Epoch 93/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 12.9952 - mae: 1.4031
# Epoch 94/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.9479 - mae: 1.3678
# Epoch 95/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 13.3549 - mae: 1.1890
# Epoch 96/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.5963 - mae: 1.1881
# Epoch 97/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.1628 - mae: 1.3715
# Epoch 98/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.3008 - mae: 1.3792
# Epoch 99/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.6045 - mae: 1.1773
# Epoch 100/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 14.4368 - mae: 1.4361
# Epoch 1/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - loss: 25.6349 - mae: 2.6648
# Epoch 2/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 18.9773 - mae: 2.4543
# Epoch 3/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 18.7928 - mae: 2.4760
# Epoch 4/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 16.9558 - mae: 2.3194
# Epoch 5/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 18.2392 - mae: 2.4101
# Epoch 6/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 16.9220 - mae: 2.3305
# Epoch 7/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 17.2164 - mae: 2.3038
# Epoch 8/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 14.9374 - mae: 2.2337
# Epoch 9/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 18.6817 - mae: 2.3060
# Epoch 10/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 16.4936 - mae: 2.2016
# Epoch 11/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 16.3702 - mae: 2.2251
# Epoch 12/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 15.8232 - mae: 2.2042
# Epoch 13/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 14.9720 - mae: 2.1626
# Epoch 14/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 14.8048 - mae: 2.1576
# Epoch 15/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 14.4791 - mae: 2.1315
# Epoch 16/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 14.4202 - mae: 2.0751
# Epoch 17/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 14.4608 - mae: 2.1104
# Epoch 18/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 13.8417 - mae: 2.0826
# Epoch 19/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 14.2648 - mae: 2.0623
# Epoch 20/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 14.7873 - mae: 2.1130
# Epoch 21/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 14.3380 - mae: 2.1179
# Epoch 22/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 13.4999 - mae: 2.0190
# Epoch 23/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 13.6058 - mae: 2.0396
# Epoch 24/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 17.1376 - mae: 2.1587
# Epoch 25/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 12.7540 - mae: 1.9479
# Epoch 26/100
# ...
# Epoch 12/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.2678 - mae: 1.3461
# Epoch 13/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.5431 - mae: 1.3208
# Epoch 14/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.8034 - mae: 1.3113
# Epoch 15/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.2080 - mae: 1.3268
# Epoch 16/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.9089 - mae: 1.2915
# Epoch 17/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 11.5972 - mae: 1.4252
# Epoch 18/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.3259 - mae: 1.2908
# Epoch 19/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 10.3757 - mae: 1.3736
# Epoch 20/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.6260 - mae: 1.3480
# Epoch 21/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 10.7140 - mae: 1.3667
# Epoch 22/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 10.5358 - mae: 1.3038
# Epoch 23/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.3989 - mae: 1.2641
# Epoch 24/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.4686 - mae: 1.2442
# Epoch 25/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.1624 - mae: 1.2915
# Epoch 26/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.1860 - mae: 1.2870
# Epoch 27/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.0709 - mae: 1.2758
# Epoch 28/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 8.7050 - mae: 1.2634
# Epoch 29/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.4071 - mae: 1.3019
# Epoch 30/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 9.2400 - mae: 1.3362
# Epoch 31/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.0493 - mae: 1.2735
# Epoch 32/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.2309 - mae: 1.3429
# Epoch 33/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.6254 - mae: 1.2158
# Epoch 34/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.5630 - mae: 1.2160
# Epoch 35/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.8551 - mae: 1.3048
# Epoch 36/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.8963 - mae: 1.2402
# Epoch 37/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.6556 - mae: 1.2354
# Epoch 38/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 10.9487 - mae: 1.3782
# Epoch 39/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.4833 - mae: 1.2460
# Epoch 40/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.8939 - mae: 1.1925
# Epoch 41/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.8643 - mae: 1.1464
# Epoch 42/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 9.0075 - mae: 1.2767
# Epoch 43/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.7620 - mae: 1.2345
# Epoch 44/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.2014 - mae: 1.2339
# Epoch 45/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.1010 - mae: 1.2881
# Epoch 46/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 6.4940 - mae: 1.1362
# Epoch 47/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.3743 - mae: 1.1557
# Epoch 48/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.5927 - mae: 1.3365
# Epoch 49/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.5018 - mae: 1.2086
# Epoch 50/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.1866 - mae: 1.2545
# Epoch 51/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 8.1112 - mae: 1.2615
# Epoch 52/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 6.9060 - mae: 1.1838
# Epoch 53/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.1156 - mae: 1.2142
# Epoch 54/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.2199 - mae: 1.1699
# Epoch 55/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.3591 - mae: 1.2439
# Epoch 56/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.9217 - mae: 1.2321
# Epoch 57/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.4027 - mae: 1.2953
# Epoch 58/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.1477 - mae: 1.1681
# Epoch 59/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.0961 - mae: 1.1911
# Epoch 60/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 8.0703 - mae: 1.2503
# Epoch 61/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 6.6139 - mae: 1.1657
# Epoch 62/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.3562 - mae: 1.2073
# Epoch 63/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.9557 - mae: 1.2510
# Epoch 64/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.5242 - mae: 1.1751
# Epoch 65/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.3442 - mae: 1.1398
# Epoch 66/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.4377 - mae: 1.2297
# Epoch 67/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.1342 - mae: 1.2323
# Epoch 68/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.4426 - mae: 1.2402
# Epoch 69/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.8440 - mae: 1.2040
# Epoch 70/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.1206 - mae: 1.1572
# Epoch 71/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.3342 - mae: 1.3245
# Epoch 72/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 6.7398 - mae: 1.1381
# Epoch 73/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.2176 - mae: 1.1812
# Epoch 74/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.3988 - mae: 1.1932
# Epoch 75/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 9.1138 - mae: 1.2043
# Epoch 76/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.5231 - mae: 1.1911
# Epoch 77/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.3388 - mae: 1.2842
# Epoch 78/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 8.1502 - mae: 1.2753
# Epoch 79/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 9.1401 - mae: 1.2022
# Epoch 80/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 8.8927 - mae: 1.2399
# Epoch 81/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.5035 - mae: 1.1867
# Epoch 82/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 8.3394 - mae: 1.2822
# Epoch 83/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.9596 - mae: 1.2602
# Epoch 84/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 6.3363 - mae: 1.1083
# Epoch 85/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.4737 - mae: 1.1846
# Epoch 86/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.6597 - mae: 1.1882
# Epoch 87/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 6.5891 - mae: 1.1507
# Epoch 88/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.8621 - mae: 1.2429
# Epoch 89/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 6.3655 - mae: 1.1350
# Epoch 90/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 6.4873 - mae: 1.1298
# Epoch 91/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.4239 - mae: 1.1976
# Epoch 92/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 8.7265 - mae: 1.2006
# Epoch 93/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 8.4502 - mae: 1.2286
# Epoch 94/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.3549 - mae: 1.1863
# Epoch 95/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.2892 - mae: 1.1891
# Epoch 96/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.2882 - mae: 1.1927
# Epoch 97/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.5119 - mae: 1.1837
# Epoch 98/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.9153 - mae: 1.1740
# Epoch 99/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.0863 - mae: 1.1339
# Epoch 100/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.3652 - mae: 1.1888
# Epoch 1/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 19s 43ms/step - loss: 22.3426 - mae: 2.3456
# Epoch 2/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 16.1199 - mae: 2.3607
# Epoch 3/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 16.4152 - mae: 2.2840
# Epoch 4/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 18.9175 - mae: 2.3435
# Epoch 5/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 16.6265 - mae: 2.2012
# Epoch 6/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 14.3490 - mae: 2.0650
# Epoch 7/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 15.8051 - mae: 2.1948
# Epoch 8/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 13.8981 - mae: 2.0565
# Epoch 9/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 14.3737 - mae: 2.1142
# Epoch 10/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 14.1608 - mae: 2.0349
# Epoch 11/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 15.0992 - mae: 2.0429
# Epoch 12/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 12.7010 - mae: 1.8936
# Epoch 13/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 15.3593 - mae: 2.0569
# Epoch 14/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 14.1147 - mae: 2.0177
# Epoch 15/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 16.1793 - mae: 1.9693
# Epoch 16/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 16.0469 - mae: 2.0390
# Epoch 17/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 13.3218 - mae: 1.9242
# Epoch 18/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 15.8007 - mae: 2.0002
# Epoch 19/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 14.0737 - mae: 1.9303
# Epoch 20/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 12.7825 - mae: 1.8946
# Epoch 21/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 12.4615 - mae: 1.8867
# Epoch 22/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 13.2497 - mae: 1.8657
# Epoch 23/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 12.4926 - mae: 1.9115
# Epoch 24/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 11.8265 - mae: 1.8301
# Epoch 25/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 13.0072 - mae: 1.8967
# Epoch 26/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 12.4822 - mae: 1.8838
# Epoch 27/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 12.3903 - mae: 1.8486
# Epoch 28/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 12.0581 - mae: 1.8716
# Epoch 29/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 12.5494 - mae: 1.8495
# Epoch 30/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 12.8388 - mae: 1.9039
# Epoch 31/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 13.8266 - mae: 1.9521
# Epoch 32/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 13.4688 - mae: 1.8897
# Epoch 33/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 12.4292 - mae: 1.8109
# Epoch 34/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 11.7313 - mae: 1.8007
# Epoch 35/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 13.1616 - mae: 1.8761
# Epoch 36/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 12.5217 - mae: 1.8431
# Epoch 37/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 12.3711 - mae: 1.8656
# Epoch 38/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 11.9109 - mae: 1.8233
# Epoch 39/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 11.8472 - mae: 1.8330
# Epoch 40/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 10.5489 - mae: 1.7101
# Epoch 41/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 12.5999 - mae: 1.8168
# Epoch 42/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 12.7747 - mae: 1.8462
# Epoch 43/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 12.9546 - mae: 1.9247
# Epoch 44/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 10.6754 - mae: 1.7593
# Epoch 45/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 10.8356 - mae: 1.7199
# Epoch 46/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 12.3928 - mae: 1.8534
# Epoch 47/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 12.1840 - mae: 1.8342
# Epoch 48/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 12.4736 - mae: 1.8755
# Epoch 49/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 12.3708 - mae: 1.8437
# Epoch 50/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 11.9060 - mae: 1.8084
# Epoch 51/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 11.6983 - mae: 1.7762
# Epoch 52/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 11.8764 - mae: 1.8016
# Epoch 53/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 10.7298 - mae: 1.7461
# Epoch 54/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 12.3290 - mae: 1.8014
# Epoch 55/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 11.3314 - mae: 1.7464
# Epoch 56/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 11.5454 - mae: 1.7617
# Epoch 57/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 13.4015 - mae: 1.9003
# Epoch 58/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 12.5125 - mae: 1.8526
# Epoch 59/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 11.5364 - mae: 1.7600
# Epoch 60/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 11.0273 - mae: 1.8044
# Epoch 61/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 10.9021 - mae: 1.7601
# Epoch 62/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 11.9382 - mae: 1.8541
# Epoch 63/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 10.7593 - mae: 1.7526
# Epoch 64/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 11.2145 - mae: 1.7390
# Epoch 65/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 11.7132 - mae: 1.7691
# Epoch 66/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 11.1361 - mae: 1.7603
# Epoch 67/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 10.2842 - mae: 1.6986
# Epoch 68/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.8000 - mae: 1.6440
# Epoch 69/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 10.6000 - mae: 1.7349
# Epoch 70/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 10.4433 - mae: 1.7304
# Epoch 71/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.8087 - mae: 1.7010
# Epoch 72/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 10.9124 - mae: 1.7140
# Epoch 73/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.9838 - mae: 1.6567
# Epoch 74/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 10.8298 - mae: 1.7462
# Epoch 75/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.0016 - mae: 1.6545
# Epoch 76/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 11.9360 - mae: 1.7552
# Epoch 77/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 10.8794 - mae: 1.7885
# Epoch 78/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 11.1618 - mae: 1.7779
# Epoch 79/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 10.9970 - mae: 1.7013
# Epoch 80/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 10.9844 - mae: 1.7930
# Epoch 81/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 11.4393 - mae: 1.7641
# Epoch 82/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 10.2503 - mae: 1.7212
# Epoch 83/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 11.7604 - mae: 1.7988
# Epoch 84/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 9.9559 - mae: 1.6671
# Epoch 85/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 10.9449 - mae: 1.7448
# Epoch 86/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 10.0049 - mae: 1.7168
# Epoch 87/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 11.7116 - mae: 1.7831
# Epoch 88/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 9.9701 - mae: 1.6548
# Epoch 89/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 10.8062 - mae: 1.7734
# Epoch 90/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.4582 - mae: 1.6371
# Epoch 91/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 11.1991 - mae: 1.7211
# Epoch 92/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 11.1195 - mae: 1.7188
# Epoch 93/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 11.2441 - mae: 1.7591
# Epoch 94/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 10.4999 - mae: 1.6879
# Epoch 95/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.4470 - mae: 1.6509
# Epoch 96/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.7834 - mae: 1.7049
# Epoch 97/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 9.7321 - mae: 1.6852
# Epoch 98/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 10.6162 - mae: 1.7201
# Epoch 99/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 10.2825 - mae: 1.7079
# Epoch 100/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 10.4365 - mae: 1.6793

# %%
# Evaluate model
from sklearn.metrics import root_mean_squared_error

for i in range(N_CLUSTERS):
	print(f"Cluster {i}")
	april_model = regression_april_models[i]
	october_model = regression_october_models[i]
	april_X_train = regression_april_dataset_train_X[i]
	april_Y_train = regression_april_dataset_train_Y[i]
	april_X_test = regression_april_dataset_test_X[i]
	april_Y_test = regression_april_dataset_test_Y[i]
	october_X_train = regression_october_dataset_train_X[i]
	october_Y_train = regression_october_dataset_train_Y[i]
	october_X_test = regression_october_dataset_test_X[i]
	october_Y_test = regression_october_dataset_test_Y[i]
	april_train_pred = april_model.predict(april_X_train)
	april_test_pred = april_model.predict(april_X_test)
	october_train_pred = october_model.predict(october_X_train)
	october_test_pred = october_model.predict(october_X_test)
	april_train_rmse = root_mean_squared_error(april_Y_train, april_train_pred)
	april_test_rmse = root_mean_squared_error(april_Y_test, april_test_pred)
	october_train_rmse = root_mean_squared_error(october_Y_train, october_train_pred)
	october_test_rmse = root_mean_squared_error(october_Y_test, october_test_pred)

	# Print nan count
	print(f"April Train nan: {np.isnan(april_train_pred).sum()}")
	print(f"April Test nan: {np.isnan(april_test_pred).sum()}")
	print(f"October Train nan: {np.isnan(october_train_pred).sum()}")
	print(f"October Test nan: {np.isnan(october_test_pred).sum()}")
	# Print mean
	print(f"April Train_pred mean: {np.mean(april_train_pred)}")
	print(f"April Test_pred mean: {np.mean(april_test_pred)}")
	print(f"October Train_pred mean: {np.mean(october_train_pred)}")
	print(f"October Test_pred mean: {np.mean(october_test_pred)}")
	
	# Create subplots
	fig, axs = plt.subplots(2, 2, figsize=(20, 20))
	fig.suptitle(f'Cluster {i} - Predicted vs Actual Rainfall')

	# April Train
	axs[0, 0].bar(range(len(april_Y_train[-30:])), april_Y_train[-30:], label='Actual')
	axs[0, 0].bar(range(len(april_train_pred[-30:])), april_train_pred[-30:].flatten(), alpha=0.7, label='Predicted')
	axs[0, 0].set_title(f'April Train - RMSE: {april_train_rmse}')
	axs[0, 0].legend()

	# April Test
	axs[0, 1].bar(range(len(april_Y_test[-30:])), april_Y_test[-30:], label='Actual')
	axs[0, 1].bar(range(len(april_test_pred[-30:])), april_test_pred[-30:].flatten(), alpha=0.7, label='Predicted')
	axs[0, 1].set_title(f'April Test - RMSE: {april_test_rmse}')
	axs[0, 1].legend()

	# October Train
	axs[1, 0].bar(range(len(october_Y_train[-30:])), october_Y_train[-30:], label='Actual')
	axs[1, 0].bar(range(len(october_train_pred[-30:])), october_train_pred[-30:].flatten(), alpha=0.7, label='Predicted')
	axs[1, 0].set_title(f'October Train - RMSE: {october_train_rmse}')
	axs[1, 0].legend()

	# October Test
	axs[1, 1].bar(range(len(october_Y_test[-30:])), october_Y_test[-30:], label='Actual')
	axs[1, 1].bar(range(len(october_test_pred[-30:])), october_test_pred[-30:].flatten(), alpha=0.7, label='Predicted')
	axs[1, 1].set_title(f'October Test - RMSE: {october_test_rmse}')
	axs[1, 1].legend()

	plt.show()
	print("=" * 150)
# Out:
# Cluster 0
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# April Train nan: 0
# April Test nan: 0
# October Train nan: 0
# October Test nan: 0
# April Train_pred mean: 1.696947693824768
# April Test_pred mean: 1.7075029611587524
# October Train_pred mean: 1.7106342315673828
# October Test_pred mean: 1.741723895072937
# ======================================================================================================================================================
# Cluster 1
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step
# April Train nan: 0
# April Test nan: 0
# October Train nan: 0
# October Test nan: 0
# April Train_pred mean: 1.9161030054092407
# April Test_pred mean: 1.8232827186584473
# October Train_pred mean: 4.423515796661377
# October Test_pred mean: 4.1823530197143555
# ======================================================================================================================================================
# Cluster 2
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# April Train nan: 0
# April Test nan: 0
# October Train nan: 0
# October Test nan: 0
# April Train_pred mean: 1.1821521520614624
# April Test_pred mean: 1.2255885601043701
# October Train_pred mean: 1.952147364616394
# October Test_pred mean: 1.8758156299591064
# ======================================================================================================================================================
# Cluster 3
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# April Train nan: 0
# April Test nan: 0
# October Train nan: 0
# October Test nan: 0
# April Train_pred mean: 1.426230788230896
# April Test_pred mean: 1.4739872217178345
# October Train_pred mean: 2.780836820602417
# October Test_pred mean: 2.7847094535827637
# ======================================================================================================================================================

# %% [markdown]
# # Note:
# - Need refractoring (write function for \[X, y\] and scaling X_train, X_test)
# - Split train & test before SMOTE-ENN (this has to be done on training samples)
# - Classification before regression
# - Select a fixed number of features
