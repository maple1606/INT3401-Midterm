# %% [markdown]
# ### Load data

# %%
import pandas as pd
import os
from dotenv import load_dotenv

load_dotenv()
DATA_PATH=os.getenv("DATA_PATH")

month = 4

# %%
train_data = pd.read_csv(f"{DATA_PATH}/{month}/train_data_{month}.csv")
train_data['date']
train_data
# Out:
#                        date  row  col  radar  aws  imerge      tclw     cape  \
# 0       2019-04-05 00:00:00   13  104    0.0  0.0     0.0  0.797485  848.125
# 1       2019-04-05 00:00:00   13  111    0.0  0.0     0.0  0.940918  760.125
# 2       2019-04-05 00:00:00   13  115    0.0  0.0     0.0  0.940918  760.125
# 3       2019-04-05 00:00:00   13  120    0.0  0.0     0.0  1.002502  693.500
# 4       2019-04-05 00:00:00   13  132    0.0  0.0     0.0  0.215759  274.375
# ...                     ...  ...  ...    ...  ...     ...       ...      ...
# 270508  2020-04-27 23:00:00   37   92    NaN  0.0     0.0  0.032532    0.000
# 270509  2020-04-27 23:00:00   37  116    NaN  0.0     0.0  0.070801    0.000
# 270510  2020-04-27 23:00:00   38   87    NaN  0.0     0.0  0.006836    0.000
# 270511  2020-04-27 23:00:00   39   78    NaN  0.0     0.0  0.003052    0.000
# 270512  2020-04-27 23:00:00   39   83    NaN  0.0     0.0  0.003052    0.000
#
#              v250  ie  ...       b10b        i4b       b11b        i2b  \
# 0       12.786087 NaN  ...  258.70645  282.39658  275.61548  274.80203
# 1       12.678665 NaN  ...  259.29077  283.18840  276.63477  276.44022
# 2       12.678665 NaN  ...  260.48560  285.33563  279.55515  279.29578
# 3       12.528275 NaN  ...  260.08408  286.08878  278.85434  278.16708
# 4       12.110306 NaN  ...  262.62012  291.72240  285.16458  283.52197
# ...           ...  ..  ...        ...        ...        ...        ...
# 270508   5.693726 NaN  ...  252.28877  284.79565  281.38855  233.81190
# 270509   4.783569 NaN  ...  251.80576  287.40573  281.74210  231.99098
# 270510   5.889038 NaN  ...  251.80576  285.50076  281.98288  234.38295
# 270511   5.974976 NaN  ...  249.97690  283.08580  277.57410  228.87840
# 270512   5.974976 NaN  ...  250.99174  283.96280  279.94077  231.14008
#
#              b09b      b04b       vsb       b16b      b05b        irb
# 0       251.88264  0.120005  0.106313  263.86227  0.086090  276.60280
# 1       251.68250  0.138926  0.111532  265.05322  0.099782  277.95300
# 2       252.59529  0.114146  0.093913  267.24475  0.095876  281.45020
# 3       252.47002  0.116750  0.095876  266.19382  0.106313  281.15073
# 4       254.98889  0.092611  0.058044  269.79132  0.073039  287.06708
# ...           ...       ...       ...        ...       ...        ...
# 270508  241.96497  0.004687  0.002279  223.54109       NaN  283.75146
# 270509  242.17998  0.008215  0.007161  221.58864       NaN  284.18433
# 270510  241.96497  0.002344  0.003581  223.63261       NaN  284.46460
# 270511  240.40430  0.004687  0.009450  219.26062       NaN  279.60895
# 270512  241.08630  0.003125  0.004232  221.20198       NaN  282.09625
#
# [270513 rows x 40 columns]

# %%
test_data = pd.read_csv(f"{DATA_PATH}/{month}/test_data_{month}.csv")
test_data
# Out:
#                       date  row  col  radar  aws  imerge      tclw   cape  \
# 0      2020-04-30 23:00:00   35  113    NaN  0.0     0.0  0.030212  0.000
# 1      2020-04-30 23:00:00   36  115    NaN  0.0     0.0  0.030212  0.000
# 2      2020-04-30 23:00:00   37   81    NaN  0.0     0.0  0.016968  0.625
# 3      2020-04-30 23:00:00   38   87    NaN  0.0     0.0  0.009766  0.375
# 4      2020-04-30 23:00:00   39   83    NaN  0.0     0.0  0.016968  0.625
# ...                    ...  ...  ...    ...  ...     ...       ...    ...
# 35328  2020-04-30 23:00:00   27  114    NaN  0.0     0.0  0.031616  0.000
# 35329  2020-04-30 23:00:00   28  113    NaN  0.0     0.0  0.031616  0.000
# 35330  2020-04-30 23:00:00   28  117    NaN  0.0     0.0  0.037170  0.000
# 35331  2020-04-30 23:00:00   30  107    NaN  0.0     0.0  0.038086  0.000
# 35332  2020-04-30 23:00:00   30  110    NaN  0.0     0.0  0.031616  0.000
#
#            v250  ie  ...       b10b        i4b       b11b        i2b  \
# 0      5.080612 NaN  ...  247.52742  284.48935  273.65060  267.32040
# 1      5.080612 NaN  ...  247.74237  283.10764  273.92032  267.78520
# 2      5.342331 NaN  ...  248.82759  275.33252  268.73502  264.29370
# 3      5.322800 NaN  ...  251.07751  283.10880  279.49734  275.80820
# 4      5.342331 NaN  ...  250.18732  281.82114  276.63153  272.48367
# ...         ...  ..  ...        ...        ...        ...        ...
# 35328  4.943893 NaN  ...  244.72229  277.32962  264.11435  256.36353
# 35329  4.943893 NaN  ...  244.74007  279.42460  265.79636  257.55844
# 35330  5.154831 NaN  ...  244.73315  278.15262  265.53793  258.15268
# 35331  4.799362 NaN  ...  246.67015  280.62265  269.67520  262.68942
# 35332  4.943893 NaN  ...  245.62842  280.62570  268.04400  260.32160
#
#             b09b      b04b       vsb       b16b  b05b        irb
# 0      240.64526  0.018911  0.014333  259.89297   NaN  275.63470
# 1      240.65857  0.020213  0.013031  259.39160   NaN  276.40585
# 2      241.96107  0.020203  0.016947  255.37296   NaN  270.92413
# 3      242.68164  0.013031  0.011729  264.65982   NaN  282.14920
# 4      242.31941  0.018911  0.015635  264.13590   NaN  279.27206
# ...          ...       ...       ...        ...   ...        ...
# 35328  239.32043  0.014994  0.013031  248.58379   NaN  266.05173
# 35329  239.33305  0.015645  0.011729  250.52454   NaN  267.82877
# 35330  239.13155  0.016947  0.013692  250.77515   NaN  267.30673
# 35331  239.89629  0.010427  0.011078  253.28267   NaN  271.79672
# 35332  239.90137  0.014343  0.011078  252.80508   NaN  270.18576
#
# [35333 rows x 40 columns]

# %%
import missingno as msno
msno.matrix(train_data)
msno.matrix(test_data)
# Out:
# <Axes: >

# %%
def format_date_column(df, date_column='date'):
    """
    This function checks if the date column is in datetime format.
    If not, it converts the column to datetime format.

    Parameters:
    df (pd.DataFrame): The dataframe containing the date column.
    date_column (str): The name of the date column. Default is 'date'.

    Returns:
    pd.DataFrame: The dataframe with the formatted date column.
    """
    if not pd.api.types.is_datetime64_any_dtype(df[date_column]):
        df[date_column] = pd.to_datetime(
            df[date_column],  format='%Y-%m-%d %H:%M:%S')
    return df


train_data = format_date_column(train_data)
test_data = format_date_column(test_data)
important_columns = ['date', 'row', 'col', 'aws', 'imerge',
                     'tclw', 'r850', 'r250', 'v850', 'r500', 'u250']
train_data = train_data[important_columns]
test_data = test_data[important_columns]

# %%
msno.matrix(train_data)
msno.matrix(test_data)
# Out:
# <Axes: >

# %%
train_data = train_data.dropna()
test_data = test_data.dropna()
print(train_data.isna().sum())
print(test_data.isna().sum())
# Out:
# date      0
# row       0
# col       0
# aws       0
# imerge    0
# tclw      0
# r850      0
# r250      0
# v850      0
# r500      0
# u250      0
# dtype: int64
# date      0
# row       0
# col       0
# aws       0
# imerge    0
# tclw      0
# r850      0
# r250      0
# v850      0
# r500      0
# u250      0
# dtype: int64

# %%
from data_processors import DataScaler
scaler = DataScaler()
scaler.scale_data(train_data, test_data)
# Out:
# aws
# imerge
# tclw
# r850
# r250
# v850
# r500
# u250

# %% [markdown]
# ### Create Sequence data

# %%
TIME_STEPS=6
from data_processors import GetData

X_train, y_train, X_test, y_test = GetData.get_non_cluster_sequence_data(train_df=train_data, test_df=test_data, time_step=TIME_STEPS)

# %%
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (168949, 6, 8), y_train shape: (168949,)
# X_test shape: (21258, 6, 8), y_test shape: (21258,)

# %%
import numpy as np
np.random.seed(42)

threshold = 0.02

indices_y_gt = np.where(y_test >= threshold)[0]
indices_y_lt = np.where(y_test < threshold)[0]

print(f"Number of samples with y >= {threshold}: {len(indices_y_gt)}")
print(f"Number of samples with y < {threshold}: {len(indices_y_lt)}")

selected_indices_y_gt = indices_y_gt
selected_indices_y_lt = np.random.choice(indices_y_lt, 1000, replace=False)

X_train = np.concatenate((X_train[selected_indices_y_gt], X_train[selected_indices_y_lt]), axis=0)
y_train = np.concatenate((y_train[selected_indices_y_gt], y_train[selected_indices_y_lt]), axis=0)

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# Number of samples with y >= 0.02: 236
# Number of samples with y < 0.02: 21022
# X_train shape: (1236, 6, 8), y_train shape: (1236,)

# %% [markdown]
# ### Stacking models

# %%
# 5 models each with different number of layers and units
UNITS1 = [64, 64]
UNITS2 = [32, 32]
UNITS3 = [64, 128, 64]
UNITS4 = [32, 64, 32]
UNITS5 = [128, 128, 256, 256]

DROPOUT1 = [0.2, 0.2]
DROPOUT2 = [0.1, 0.1]
DROPOUT3 = [0.2, 0.3, 0.2]
DROPOUT4 = [0.1, 0.2, 0.1]
DROPOUT5 = [0.2, 0.3, 0.4, 0.5]

EPOCHS = 250
KERNEL_REGULARIZER = None
PATIENCE = 15

UNITS = [UNITS1, UNITS2, UNITS3, UNITS4, UNITS5]
DROPOUTS = [DROPOUT1, DROPOUT2, DROPOUT3, DROPOUT4, DROPOUT5]
VALIDATION_SPLIT = 0.1

# %%
from recurrent_regressor import LSTMRegressor, GRURegressor

lstm_regressors = []
gru_regressors = []

for i in range(2, 4):
    lstm_regressors.append(LSTMRegressor(units=UNITS[i], dropouts=DROPOUTS[i], kernel_regularizer=KERNEL_REGULARIZER, patience=PATIENCE, validation_split=VALIDATION_SPLIT, epochs=EPOCHS))
    gru_regressors.append(GRURegressor(units=UNITS[i], dropouts=DROPOUTS[i], kernel_regularizer=KERNEL_REGULARIZER, patience=PATIENCE, validation_split=VALIDATION_SPLIT, epochs=EPOCHS))
# Out:
# 2024-12-03 21:13:21.260384: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-03 21:13:21.279374: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-03 21:13:21.285164: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-03 21:13:22.383322: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from sklearn.ensemble import StackingRegressor
from sklearn.linear_model import LinearRegression

# Init base estimators
base_estimators = []

for i in range(len(lstm_regressors)):
    base_estimators.append((f"LSTM_{i+1}", lstm_regressors[i]))
    base_estimators.append((f"GRU_{i+1}", gru_regressors[i]))
    
# Init final estimator
final_estimator = LinearRegression(n_jobs=-1)

# Pre-fit base estimators
for name, estimator in base_estimators:
	estimator.fit(X_train, y_train)

# Init stacking regressor
stacking_regressor = StackingRegressor(estimators=base_estimators, final_estimator=final_estimator, cv="prefit", n_jobs=-1)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733235203.294136   75840 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1733235203.329202   75840 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1733235203.329506   75840 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1733235203.333814   75840 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1733235203.334036   75840 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1733235203.334230   75840 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1733235203.511146   75840 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1733235203.511384   75840 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1733235203.511573   75840 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-03 21:13:23.511704: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5493 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1060 6GB, pci bus id: 0000:03:00.0, compute capability: 6.1
# Epoch 1/250
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733235208.182286   75991 service.cc:146] XLA service 0x10ad1c10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1733235208.182341   75991 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce GTX 1060 6GB, Compute Capability 6.1
# 2024-12-03 21:13:28.311622: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-12-03 21:13:28.996476: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 25/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2410e-05
# I0000 00:00:1733235213.169749   75991 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 211ms/step - loss: 9.2421e-05 - val_loss: 4.1752e-04
# Epoch 2/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.1649e-05 - val_loss: 4.0171e-04
# Epoch 3/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.9276e-05 - val_loss: 4.0913e-04
# Epoch 4/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.3344e-05 - val_loss: 4.0217e-04
# Epoch 5/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3474e-04 - val_loss: 4.0266e-04
# Epoch 6/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.8624e-05 - val_loss: 4.0935e-04
# Epoch 7/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9587e-05 - val_loss: 3.9621e-04
# Epoch 8/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9494e-05 - val_loss: 3.9426e-04
# Epoch 9/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4528e-04 - val_loss: 4.1562e-04
# Epoch 10/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.3009e-05 - val_loss: 4.0638e-04
# Epoch 11/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1968e-04 - val_loss: 3.8824e-04
# Epoch 12/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1823e-04 - val_loss: 4.2588e-04
# Epoch 13/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5142e-05 - val_loss: 3.8477e-04
# Epoch 14/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.6404e-05 - val_loss: 4.1543e-04
# Epoch 15/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2497e-04 - val_loss: 4.0384e-04
# Epoch 16/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.7503e-05 - val_loss: 3.7185e-04
# Epoch 17/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1429e-04 - val_loss: 4.1616e-04
# Epoch 18/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.1665e-05 - val_loss: 4.1460e-04
# Epoch 19/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.7360e-05 - val_loss: 4.1527e-04
# Epoch 20/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0034e-04 - val_loss: 4.1263e-04
# Epoch 21/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6127e-04 - val_loss: 4.0928e-04
# Epoch 22/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4196e-04 - val_loss: 4.0826e-04
# Epoch 23/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0776e-04 - val_loss: 4.0381e-04
# Epoch 24/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.
250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.3999e-05 - val_loss: 4.1929e-04
# Epoch 8/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.8423e-05 - val_loss: 4.1768e-04
# Epoch 9/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.3863e-05 - val_loss: 4.0653e-04
# Epoch 10/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.5801e-05 - val_loss: 4.0791e-04
# Epoch 11/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7126e-04 - val_loss: 4.1375e-04
# Epoch 12/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4166e-04 - val_loss: 4.1776e-04
# Epoch 13/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.2332e-05 - val_loss: 4.1186e-04
# Epoch 14/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7290e-04 - val_loss: 4.1906e-04
# Epoch 15/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.8404e-05 - val_loss: 4.1227e-04
# Epoch 16/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0478e-04 - val_loss: 4.1977e-04
# Epoch 17/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.9928e-05 - val_loss: 4.1447e-04
# Epoch 18/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.0624e-05 - val_loss: 3.9826e-04
# Epoch 19/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7921e-04 - val_loss: 3.9586e-04
# Epoch 20/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.8145e-05 - val_loss: 4.2366e-04
# Epoch 21/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2102e-04 - val_loss: 4.1654e-04
# Epoch 22/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0143e-04 - val_loss: 4.2071e-04
# Epoch 23/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.0022e-05 - val_loss: 4.0617e-04
# Epoch 24/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.6609e-05 - val_loss: 4.1343e-04
# Epoch 25/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2538e-04 - val_loss: 4.1786e-04
# Epoch 26/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3908e-04 - val_loss: 4.1117e-04
# Epoch 27/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0918e-04 - val_loss: 4.1744e-04
# Epoch 28/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1980e-04 - val_loss: 4.1377e-04
# Epoch 29/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.8113e-05 - val_loss: 4.0348e-04
# Epoch 30/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1346e-04 - val_loss: 4.1343e-04
# Epoch 31/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0794e-04 - val_loss: 3.8849e-04
# Epoch 32/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4276e-04 - val_loss: 4.1978e-04
# Epoch 33/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5462e-04 - val_loss: 4.1889e-04
# Epoch 34/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0971e-04 - val_loss: 4.1800e-04
# Epoch 35/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6979e-04 - val_loss: 4.1320e-04
# Epoch 36/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2368e-04 - val_loss: 4.1401e-04
# Epoch 37/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.3072e-05 - val_loss: 3.7681e-04
# Epoch 38/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.5525e-05 - val_loss: 4.1069e-04
# Epoch 39/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3897e-04 - val_loss: 3.7859e-04
# Epoch 40/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3722e-04 - val_loss: 3.6751e-04
# Epoch 41/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.7489e-05 - val_loss: 4.0492e-04
# Epoch 42/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.8404e-05 - val_loss: 4.2117e-04
# Epoch 43/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6833e-04 - val_loss: 3.9643e-04
# Epoch 44/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9784e-05 - val_loss: 4.0620e-04
# Epoch 45/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6678e-04 - val_loss: 4.1495e-04
# Epoch 46/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.4500e-05 - val_loss: 4.0539e-04
# Epoch 47/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4170e-04 - val_loss: 3.7417e-04
# Epoch 48/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1030e-04 - val_loss: 3.9888e-04
# Epoch 49/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.6929e-05 - val_loss: 3.7849e-04
# Epoch 50/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.6506e-05 - val_loss: 3.7443e-04
# Epoch 51/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.9104e-05 - val_loss: 4.0829e-04
# Epoch 52/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.6300e-05 - val_loss: 3.6173e-04
# Epoch 53/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2572e-04 - val_loss: 4.1376e-04
# Epoch 54/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.5628e-05 - val_loss: 3.5811e-04
# Epoch 55/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0999e-04 - val_loss: 4.0436e-04
# Epoch 56/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.8533e-05 - val_loss: 3.9040e-04
# Epoch 57/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6137e-04 - val_loss: 4.0229e-04
# Epoch 58/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0319e-05 - val_loss: 3.4474e-04
# Epoch 59/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1565e-04 - val_loss: 3.5170e-04
# Epoch 60/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.2312e-05 - val_loss: 3.1000e-04
# Epoch 61/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.4583e-05 - val_loss: 3.8376e-04
# Epoch 62/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.3624e-05 - val_loss: 3.8748e-04
# Epoch 63/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5848e-04 - val_loss: 4.1651e-04
# Epoch 64/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.0205e-05 - val_loss: 3.2050e-04
# Epoch 65/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.2401e-05 - val_loss: 4.0440e-04
# Epoch 66/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.1783e-05 - val_loss: 3.6424e-04
# Epoch 67/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.9506e-05 - val_loss: 3.9302e-04
# Epoch 68/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5737e-04 - val_loss: 3.7673e-04
# Epoch 69/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.1204e-05 - val_loss: 2.9470e-04
# Epoch 70/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.3836e-05 - val_loss: 4.1761e-04
# Epoch 71/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2069e-04 - val_loss: 4.1938e-04
# Epoch 72/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.6595e-05 - val_loss: 4.1855e-04
# Epoch 73/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.7119e-05 - val_loss: 4.1686e-04
# Epoch 74/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.6849e-05 - val_loss: 4.0735e-04
# Epoch 75/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1254e-04 - val_loss: 3.8887e-04
# Epoch 76/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6022e-04 - val_loss: 4.1811e-04
# Epoch 77/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6441e-04 - val_loss: 3.9952e-04
# Epoch 78/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.7972e-05 - val_loss: 3.9580e-04
# Epoch 79/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.5609e-05 - val_loss: 3.7824e-04
# Epoch 80/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.8138e-05 - val_loss: 3.4097e-04
# Epoch 81/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.8480e-05 - val_loss: 3.7283e-04
# Epoch 82/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.6413e-05 - val_loss: 3.6938e-04
# Epoch 83/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1955e-04 - val_loss: 4.1651e-04
# Epoch 84/250
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.4040e-05 - val_loss: 4.1800e-04

# %%
# Fit stacking regressor
stacking_regressor.fit(X_train, y_train)
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step
# StackingRegressor(cv='prefit',
#                   estimators=[('LSTM_1',
#                                LSTMRegressor(dropouts=[0.2, 0.3, 0.2],
#                                              epochs=250, patience=15,
#                                              units=[64, 128, 64])),
#                               ('GRU_1',
#                                GRURegressor(dropouts=[0.2, 0.3, 0.2],
#                                             epochs=250, patience=15,
#                                             units=[64, 128, 64])),
#                               ('LSTM_2',
#                                LSTMRegressor(dropouts=[0.1, 0.2, 0.1],
#                                              epochs=250, patience=15,
#                                              units=[32, 64, 32])),
#                               ('GRU_2',
#                                GRURegressor(dropouts=[0.1, 0.2, 0.1],
#                                             epochs=250, patience=15,
#                                             units=[32, 64, 32]))],
#                   final_estimator=LinearRegression(n_jobs=-1), n_jobs=-1)

# %%
y_pred = stacking_regressor.predict(X_test)
# Out:
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step

# %%
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt

rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2_score = r2_score(y_test, y_pred)

plt.figure(figsize=(10, 5))
plt.title(f"RFR - RMSE: {rmse:.2f}, MAE: {mae:.2f}, R2: {r2_score:.2f}")
plt.scatter(y_test, y_pred, marker='o', alpha=0.5)
plt.xlabel("True values")
plt.ylabel("Predicted values")
plt.savefig("/home/hoangbaoan1901/Documents/INT3401-Midterm/refined_implementations/images/stacking_regressor_4.png")
